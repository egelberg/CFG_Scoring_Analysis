# %% [markdown]
# # All Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:.2f}'.format

# %%
import json

with open('Women/2019_games.json') as f:
    data = json.load(f)
    
data.keys()
# Out:
# dict_keys(['sort', 'pagination', 'cachekey', 'dataType', 'competition', 'leaderboardRows', 'version', 'ordinals', 'totalPages', 'currentPage'])

# %%
leaderboard = data['leaderboardRows']

# %%
leaderboard
# Out:
# [{'cf_rank_order': '',
#   'entrant': {'affiliateId': 44632,
#    'affiliateName': 'CrossFit Mayhem',
#    'age': 25,
#    'bibId': '017',
#    'competitorId': 163097,
#    'competitorName': 'Tia-Clair Toomey',
#    'countryCode': None,
#    'countryOfOriginCode': 'AU',
#    'countryOfOriginName': 'Australia',
#    'divisionId': '02',
#    'firstName': 'Tia-Clair',
#    'gender': 'F',
#    'height': '5\'4"',
#    'lastName': 'Toomey',
#    'profession': 0,
#    'profilePicS3key': 'b8a69-P163097_3-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'ACT',
#    'teamCaptain': 0,
#    'weight': '128 lbs'},
#   'overallRank': '1',
#   'overallScore': '1071',
#   'scores': [{'breakdown': '100 pts',
#     'exists': True,
#     'heat': 3,
#     'judge': '',
#     'lane': 23,
#     'location': '',
#     'mobileScoreDisplay': '16:56.63, 100 pts',
#     'ordinal': 1,
#     'points': '100',
#     'rank': '1',
#     'scoreDisplay': '16:56.63',
#     'scoreIdentifier': '0000',
#     'time': '16:56.63',
#     'workoutrank': '1',
#     'workoutresult': '--'},
#    {'breakdown': '78 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 20,
#     'location': '',
#     'mobileScoreDisplay': '6:59.75, 78 pts',
#     'ordinal': 2,
#     'points': '78',
#     'rank': '12',
#     'scoreDisplay': '6:59.75',
#     'scoreIdentifier': '0000',
#     'time': '6:59.75',
#     'workoutrank': '12',
#     'workoutresult': '--'},
#    {'breakdown': '98 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 24,
#     'location': '',
#     'mobileScoreDisplay': '27:11.18, 98 pts',
#     'ordinal': 3,
#     'points': '98',
#     'rank': '2',
#     'scoreDisplay': '27:11.18',
#     'scoreIdentifier': '0000',
#     'time': '27:11.18',
#     'workoutrank': '2',
#     'workoutresult': '--'},
#    {'breakdown': '67 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 10,
#     'location': '',
#     'mobileScoreDisplay': '1:47.66, 67 pts',
#     'ordinal': 4,
#     'points': '67',
#     'rank': '12',
#     'scoreDisplay': '1:47.66',
#     'scoreIdentifier': '0000',
#     'time': '1:47.66',
#     'workoutrank': '12',
#     'workoutresult': '--'},
#    {'breakdown': '88 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 8,
#     'location': '',
#     'mobileScoreDisplay': '656 rep, 88 pts',
#     'ordinal': 5,
#     'points': '88',
#     'rank': '4',
#     'scoreDisplay': '656 rep',
#     'scoreIdentifier': '0000',
#     'time': '656',
#     'workoutrank': '4',
#     'workoutresult': '--'},
#    {'breakdown': '90 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 1,
#     'location': '',
#     'mobileScoreDisplay': '18 pt, 90 pts',
#     'ordinal': 6,
#     'points': '90',
#     'rank': '3',
#     'scoreDisplay': '18 pt',
#     'scoreIdentifier': '0000',
#     'time': '18',
#     'workoutrank': '3',
#     'workoutresult': '--'},
#    {'breakdown': '100 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 5,
#     'location': '',
#     'mobileScoreDisplay': '14:07.10, 100 pts',
#     'ordinal': 7,
#     'points': '100',
#     'rank': '1',
#     'scoreDisplay': '14:07.10',
#     'scoreIdentifier': '0000',
#     'time': '14:07.10',
#     'workoutrank': '1',
#     'workoutresult': '--'},
#    {'breakdown': '100 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 10,
#     'location': '',
#     'mobileScoreDisplay': '265.0 lb, 100 pts',
#     'ordinal': 8,
#     'points': '100',
#     'rank': '1',
#     'scoreDisplay': '265.0 lb',
#     'scoreIdentifier': '0000',
#     'time': '265.0',
#     'workoutrank': '1',
#     'workoutresult': '--'},
#    {'breakdown': '100 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 1,
#     'location': '',
#     'mobileScoreDisplay': '25:12.25, 100 pts',
#     'ordinal': 9,
#     'points': '100',
#     'rank': '1',
#     'scoreDisplay': '25:12.25',
#     'scoreIdentifier': '0000',
#     'time': '25:12.25',
#     'workoutrank': '1',
#     'workoutresult': '--'},
#    {'breakdown': '70 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 3,
#     'location': '',
#     'mobileScoreDisplay': '5:44.63, 70 pts',
#     'ordinal': 10,
#     'points': '70',
#     'rank': '4',
#     'scoreDisplay': '5:44.63',
#     'scoreIdentifier': '0000',
#     'time': '5:44.63',
#     'workoutrank': '4',
#     'workoutresult': '--'},
#    {'breakdown': '80 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 3,
#     'location': '',
#     'mobileScoreDisplay': '3:14.03, 80 pts',
#     'ordinal': 11,
#     'points': '80',
#     'rank': '3',
#     'scoreDisplay': '3:14.03',
#     'scoreIdentifier': '0000',
#     'time': '3:14.03',
#     'workoutrank': '3',
#     'workoutresult': '--'},
#    {'breakdown': '100 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 5,
#     'location': '',
#     'mobileScoreDisplay': '8:25.09, 100 pts',
#     'ordinal': 12,
#     'points': '100',
#     'rank': '1',
#     'scoreDisplay': '8:25.09',
#     'scoreIdentifier': '0000',
#     'time': '8:25.09',
#     'workoutrank': '1',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44731,
#    'affiliateName': 'CrossFit Oslo',
#    'age': 33,
#    'bibId': '122',
#    'competitorId': 120480,
#    'competitorName': 'Kristin Holte',
#    'countryCode': None,
#    'countryOfOriginCode': 'NO',
#    'countryOfOriginName': 'Norway',
#    'divisionId': '02',
#    'firstName': 'Kristin',
#    'gender': 'F',
#    'height': '5\'4"',
#    'lastName': 'Holte',
#    'profession': 0,
#    'profilePicS3key': 'df164-P120480_7-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'ACT',
#    'teamCaptain': 0,
#    'weight': '130 lbs'},
#   'overallRank': '2',
#   'overallScore': '876',
#   'scores': [{'breakdown': '88 pts',
#     'exists': True,
#     'heat': 3,
#     'judge': '',
#     'lane': 27,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+2, 88 pts',
#     'ordinal': 1,
#     'points': '88',
#     'rank': '7',
#     'scoreDisplay': 'CAP+2',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+2',
#     'workoutrank': '7',
#     'workoutresult': '--'},
#    {'breakdown': '90 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 17,
#     'location': '',
#     'mobileScoreDisplay': '6:43.32, 90 pts',
#     'ordinal': 2,
#     'points': '90',
#     'rank': '6',
#     'scoreDisplay': '6:43.32',
#     'scoreIdentifier': '0000',
#     'time': '6:43.32',
#     'workoutrank': '6',
#     'workoutresult': '--'},
#    {'breakdown': '96 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 27,
#     'location': '',
#     'mobileScoreDisplay': '27:12.24, 96 pts',
#     'ordinal': 3,
#     'points': '96',
#     'rank': '3',
#     'scoreDisplay': '27:12.24',
#     'scoreIdentifier': '0000',
#     'time': '27:12.24',
#     'workoutrank': '3',
#     'workoutresult': '--'},
#    {'breakdown': '46 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 11,
#     'location': '',
#     'mobileScoreDisplay': '2:00.54, 46 pts',
#     'ordinal': 4,
#     'points': '46',
#     'rank': '19',
#     'scoreDisplay': '2:00.54',
#     'scoreIdentifier': '0000',
#     'time': '2:00.54',
#     'workoutrank': '19',
#     'workoutresult': '--'},
#    {'breakdown': '96 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 7,
#     'location': '',
#     'mobileScoreDisplay': '675 rep, 96 pts',
#     'ordinal': 5,
#     'points': '96',
#     'rank': '2',
#     'scoreDisplay': '675 rep',
#     'scoreIdentifier': '0000',
#     'time': '675',
#     'workoutrank': '2',
#     'workoutresult': '--'},
#    {'breakdown': '100 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 3,
#     'location': '',
#     'mobileScoreDisplay': '20 pt, 100 pts',
#     'ordinal': 6,
#     'points': '100',
#     'rank': '1',
#     'scoreDisplay': '20 pt',
#     'scoreIdentifier': '0000',
#     'time': '20',
#     'workoutrank': '1',
#     'workoutresult': '--'},
#    {'breakdown': '60 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 6,
#     'location': '',
#     'mobileScoreDisplay': '16:10.92, 60 pts',
#     'ordinal': 7,
#     'points': '60',
#     'rank': '5',
#     'scoreDisplay': '16:10.92',
#     'scoreIdentifier': '0000',
#     'time': '16:10.92',
#     'workoutrank': '5',
#     'workoutresult': '--'},
#    {'breakdown': '60 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 9,
#     'location': '',
#     'mobileScoreDisplay': '225.0 lb, 60 pts',
#     'ordinal': 8,
#     'points': '60',
#     'rank': '5',
#     'scoreDisplay': '225.0 lb',
#     'scoreIdentifier': '0000',
#     'time': '225.0',
#     'workoutrank': '5',
#     'workoutresult': '--'},
#    {'breakdown': '50 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 2,
#     'location': '',
#     'mobileScoreDisplay': '30:17.62, 50 pts',
#     'ordinal': 9,
#     'points': '50',
#     'rank': '6',
#     'scoreDisplay': '30:17.62',
#     'scoreIdentifier': '0000',
#     'time': '30:17.62',
#     'workoutrank': '6',
#     'workoutresult': '--'},
#    {'breakdown': '80 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 4,
#     'location': '',
#     'mobileScoreDisplay': '5:43.70, 80 pts',
#     'ordinal': 10,
#     'points': '80',
#     'rank': '3',
#     'scoreDisplay': '5:43.70',
#     'scoreIdentifier': '0000',
#     'time': '5:43.70',
#     'workoutrank': '3',
#     'workoutresult': '--'},
#    {'breakdown': '40 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 4,
#     'location': '',
#     'mobileScoreDisplay': '3:49.14, 40 pts',
#     'ordinal': 11,
#     'points': '40',
#     'rank': '7',
#     'scoreDisplay': '3:49.14',
#     'scoreIdentifier': '0000',
#     'time': '3:49.14',
#     'workoutrank': '7',
#     'workoutresult': '--'},
#    {'breakdown': '70 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 6,
#     'location': '',
#     'mobileScoreDisplay': '9:38.26, 70 pts',
#     'ordinal': 12,
#     'points': '70',
#     'rank': '4',
#     'scoreDisplay': '9:38.26',
#     'scoreIdentifier': '0000',
#     'time': '9:38.26',
#     'workoutrank': '4',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44663,
#    'affiliateName': 'CrossFit Yas',
#    'age': 28,
#    'bibId': '123',
#    'competitorId': 264512,
#    'competitorName': 'Jamie Greene',
#    'countryCode': None,
#    'countryOfOriginCode': 'NZ',
#    'countryOfOriginName': 'New Zealand',
#    'divisionId': '02',
#    'firstName': 'Jamie',
#    'gender': 'F',
#    'height': '5\'4"',
#    'lastName': 'Greene',
#    'profession': 0,
#    'profilePicS3key': '101af-P264512_2-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'ACT',
#    'teamCaptain': 0,
#    'weight': '135 lbs'},
#   'overallRank': '3',
#   'overallScore': '851',
#   'scores': [{'breakdown': '96 pts',
#     'exists': True,
#     'heat': 3,
#     'judge': '',
#     'lane': 24,
#     'location': '',
#     'mobileScoreDisplay': '19:00.67, 96 pts',
#     'ordinal': 1,
#     'points': '96',
#     'rank': '3',
#     'scoreDisplay': '19:00.67',
#     'scoreIdentifier': '0000',
#     'time': '19:00.67',
#     'workoutrank': '3',
#     'workoutresult': '--'},
#    {'breakdown': '54 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 19,
#     'location': '',
#     'mobileScoreDisplay': '7:41.94, 54 pts',
#     'ordinal': 2,
#     'points': '54',
#     'rank': '24',
#     'scoreDisplay': '7:41.94',
#     'scoreIdentifier': '0000',
#     'time': '7:41.94',
#     'workoutrank': '24',
#     'workoutresult': '--'},
#    {'breakdown': '58 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 30,
#     'location': '',
#     'mobileScoreDisplay': '30:30.81, 58 pts',
#     'ordinal': 3,
#     'points': '58',
#     'rank': '22',
#     'scoreDisplay': '30:30.81',
#     'scoreIdentifier': '0000',
#     'time': '30:30.81',
#     'workoutrank': '22',
#     'workoutresult': '--'},
#    {'breakdown': '91 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 5,
#     'location': '',
#     'mobileScoreDisplay': '1:35.70, 91 pts',
#     'ordinal': 4,
#     'points': '91',
#     'rank': '4',
#     'scoreDisplay': '1:35.70',
#     'scoreIdentifier': '0000',
#     'time': '1:35.70',
#     'workoutrank': '4',
#     'workoutresult': '--'},
#    {'breakdown': '92 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 6,
#     'location': '',
#     'mobileScoreDisplay': '664 rep, 92 pts',
#     'ordinal': 5,
#     'points': '92',
#     'rank': '3',
#     'scoreDisplay': '664 rep',
#     'scoreIdentifier': '0000',
#     'time': '664',
#     'workoutrank': '3',
#     'workoutresult': '--'},
#    {'breakdown': '80 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 4,
#     'location': '',
#     'mobileScoreDisplay': '16 pt, 80 pts',
#     'ordinal': 6,
#     'points': '80',
#     'rank': '5',
#     'scoreDisplay': '16 pt',
#     'scoreIdentifier': '0000',
#     'time': '16',
#     'workoutrank': '5',
#     'workoutresult': '--'},
#    {'breakdown': '70 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 4,
#     'location': '',
#     'mobileScoreDisplay': '15:32.03, 70 pts',
#     'ordinal': 7,
#     'points': '70',
#     'rank': '4',
#     'scoreDisplay': '15:32.03',
#     'scoreIdentifier': '0000',
#     'time': '15:32.03',
#     'workoutrank': '4',
#     'workoutresult': '--'},
#    {'breakdown': '50 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 8,
#     'location': '',
#     'mobileScoreDisplay': '220.0 lb, 50 pts',
#     'ordinal': 8,
#     'points': '50',
#     'rank': '6',
#     'scoreDisplay': '220.0 lb',
#     'scoreIdentifier': '0000',
#     'time': '220.0',
#     'workoutrank': '6',
#     'workoutresult': '--'},
#    {'breakdown': '70 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 3,
#     'location': '',
#     'mobileScoreDisplay': '28:32.16, 70 pts',
#     'ordinal': 9,
#     'points': '70',
#     'rank': '4',
#     'scoreDisplay': '28:32.16',
#     'scoreIdentifier': '0000',
#     'time': '28:32.16',
#     'workoutrank': '4',
#     'workoutresult': '--'},
#    {'breakdown': '50 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 2,
#     'location': '',
#     'mobileScoreDisplay': '5:52.21, 50 pts',
#     'ordinal': 10,
#     'points': '50',
#     'rank': '6',
#     'scoreDisplay': '5:52.21',
#     'scoreIdentifier': '0000',
#     'time': '5:52.21',
#     'workoutrank': '6',
#     'workoutresult': '--'},
#    {'breakdown': '50 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 2,
#     'location': '',
#     'mobileScoreDisplay': '3:35.62, 50 pts',
#     'ordinal': 11,
#     'points': '50',
#     'rank': '6',
#     'scoreDisplay': '3:35.62',
#     'scoreIdentifier': '0000',
#     'time': '3:35.62',
#     'workoutrank': '6',
#     'workoutresult': '--'},
#    {'breakdown': '90 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 7,
#     'location': '',
#     'mobileScoreDisplay': '9:14.71, 90 pts',
#     'ordinal': 12,
#     'points': '90',
#     'rank': '2',
#     'scoreDisplay': '9:14.71',
#     'scoreIdentifier': '0000',
#     'time': '9:14.71',
#     'workoutrank': '2',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44608,
#    'affiliateName': 'CrossFit New England',
#    'age': 26,
#    'bibId': '015',
#    'competitorId': 55121,
#    'competitorName': 'Katrin Tanja Davidsdottir',
#    'countryCode': None,
#    'countryOfOriginCode': 'IS',
#    'countryOfOriginName': 'Iceland',
#    'divisionId': '02',
#    'firstName': 'Katrín Tanja',
#    'gender': 'F',
#    'height': '5\'7"',
#    'lastName': 'Davidsdottir',
#    'profession': 0,
#    'profilePicS3key': 'ee582-P55121_22-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'ACT',
#    'teamCaptain': 0,
#    'weight': '150 lbs'},
#   'overallRank': '4',
#   'overallScore': '784',
#   'scores': [{'breakdown': '60 pts',
#     'exists': True,
#     'heat': 3,
#     'judge': '',
#     'lane': 32,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+9, 60 pts',
#     'ordinal': 1,
#     'points': '60',
#     'rank': '21',
#     'scoreDisplay': 'CAP+9',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+9',
#     'workoutrank': '21',
#     'workoutresult': '--'},
#    {'breakdown': '82 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 10,
#     'location': '',
#     'mobileScoreDisplay': '6:58.42, 82 pts',
#     'ordinal': 2,
#     'points': '82',
#     'rank': '10',
#     'scoreDisplay': '6:58.42',
#     'scoreIdentifier': '0000',
#     'time': '6:58.42',
#     'workoutrank': '10',
#     'workoutresult': '--'},
#    {'breakdown': '92 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 31,
#     'location': '',
#     'mobileScoreDisplay': '27:52.61, 92 pts',
#     'ordinal': 3,
#     'points': '92',
#     'rank': '5',
#     'scoreDisplay': '27:52.61',
#     'scoreIdentifier': '0000',
#     'time': '27:52.61',
#     'workoutrank': '5',
#     'workoutresult': '--'},
#    {'breakdown': '30 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 13,
#     'location': '',
#     'mobileScoreDisplay': '2:07.84, 30 pts',
#     'ordinal': 4,
#     'points': '30',
#     'rank': '26',
#     'scoreDisplay': '2:07.84',
#     'scoreIdentifier': '0000',
#     'time': '2:07.84',
#     'workoutrank': '26',
#     'workoutresult': '--'},
#    {'breakdown': '60 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 1,
#     'location': '',
#     'mobileScoreDisplay': '590 rep, 60 pts',
#     'ordinal': 5,
#     'points': '60',
#     'rank': '11',
#     'scoreDisplay': '590 rep',
#     'scoreIdentifier': '0000',
#     'time': '590',
#     'workoutrank': '11',
#     'workoutresult': '--'},
#    {'breakdown': '60 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 11,
#     'location': '',
#     'mobileScoreDisplay': '12 pt, 60 pts',
#     'ordinal': 6,
#     'points': '60',
#     'rank': '9',
#     'scoreDisplay': '12 pt',
#     'scoreIdentifier': '0000',
#     'time': '12',
#     'workoutrank': '9',
#     'workoutresult': '--'},
#    {'breakdown': '80 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 1,
#     'location': '',
#     'mobileScoreDisplay': '15:10.09, 80 pts',
#     'ordinal': 7,
#     'points': '80',
#     'rank': '3',
#     'scoreDisplay': '15:10.09',
#     'scoreIdentifier': '0000',
#     'time': '15:10.09',
#     'workoutrank': '3',
#     'workoutresult': '--'},
#    {'breakdown': '70 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 6,
#     'location': '',
#     'mobileScoreDisplay': '230.0 lb, 70 pts',
#     'ordinal': 8,
#     'points': '70',
#     'rank': '4',
#     'scoreDisplay': '230.0 lb',
#     'scoreIdentifier': '0000',
#     'time': '230.0',
#     'workoutrank': '4',
#     'workoutresult': '--'},
#    {'breakdown': '30 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 5,
#     'location': '',
#     'mobileScoreDisplay': '32:36.98, 30 pts',
#     'ordinal': 9,
#     'points': '30',
#     'rank': '8',
#     'scoreDisplay': '32:36.98',
#     'scoreIdentifier': '0000',
#     'time': '32:36.98',
#     'workoutrank': '8',
#     'workoutresult': '--'},
#    {'breakdown': '100 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 1,
#     'location': '',
#     'mobileScoreDisplay': '5:09.87, 100 pts',
#     'ordinal': 10,
#     'points': '100',
#     'rank': '1',
#     'scoreDisplay': '5:09.87',
#     'scoreIdentifier': '0000',
#     'time': '5:09.87',
#     'workoutrank': '1',
#     'workoutresult': '--'},
#    {'breakdown': '100 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 1,
#     'location': '',
#     'mobileScoreDisplay': '2:53.29, 100 pts',
#     'ordinal': 11,
#     'points': '100',
#     'rank': '1',
#     'scoreDisplay': '2:53.29',
#     'scoreIdentifier': '0000',
#     'time': '2:53.29',
#     'workoutrank': '1',
#     'workoutresult': '--'},
#    {'breakdown': '20 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 4,
#     'location': '',
#     'mobileScoreDisplay': '10:56.22, 20 pts',
#     'ordinal': 12,
#     'points': '20',
#     'rank': '9',
#     'scoreDisplay': '10:56.22',
#     'scoreIdentifier': '0000',
#     'time': '10:56.22',
#     'workoutrank': '9',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44589,
#    'affiliateName': 'CrossFit Spot',
#    'age': 30,
#    'bibId': '103',
#    'competitorId': 305891,
#    'competitorName': 'Karissa Pearce',
#    'countryCode': None,
#    'countryOfOriginCode': 'US',
#    'countryOfOriginName': 'United States',
#    'divisionId': '02',
#    'firstName': 'Karissa',
#    'gender': 'F',
#    'height': '5\'3"',
#    'lastName': 'Pearce',
#    'profession': 0,
#    'profilePicS3key': '17c8c-P305891_3-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'ACT',
#    'teamCaptain': 0,
#    'weight': '139 lbs'},
#   'overallRank': '5',
#   'overallScore': '714',
#   'scores': [{'breakdown': '98 pts',
#     'exists': True,
#     'heat': 3,
#     'judge': '',
#     'lane': 22,
#     'location': '',
#     'mobileScoreDisplay': '18:16.35, 98 pts',
#     'ordinal': 1,
#     'points': '98',
#     'rank': '2',
#     'scoreDisplay': '18:16.35',
#     'scoreIdentifier': '0000',
#     'time': '18:16.35',
#     'workoutrank': '2',
#     'workoutresult': '--'},
#    {'breakdown': '96 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 21,
#     'location': '',
#     'mobileScoreDisplay': '6:32.22, 96 pts',
#     'ordinal': 2,
#     'points': '96',
#     'rank': '3',
#     'scoreDisplay': '6:32.22',
#     'scoreIdentifier': '0000',
#     'time': '6:32.22',
#     'workoutrank': '3',
#     'workoutresult': '--'},
#    {'breakdown': '76 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 25,
#     'location': '',
#     'mobileScoreDisplay': '29:25.99, 76 pts',
#     'ordinal': 3,
#     'points': '76',
#     'rank': '13',
#     'scoreDisplay': '29:25.99',
#     'scoreIdentifier': '0000',
#     'time': '29:25.99',
#     'workoutrank': '13',
#     'workoutresult': '--'},
#    {'breakdown': '49 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 9,
#     'location': '',
#     'mobileScoreDisplay': '1:59.41, 49 pts',
#     'ordinal': 4,
#     'points': '49',
#     'rank': '18',
#     'scoreDisplay': '1:59.41',
#     'scoreIdentifier': '0000',
#     'time': '1:59.41',
#     'workoutrank': '18',
#     'workoutresult': '--'},
#    {'breakdown': '100 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 10,
#     'location': '',
#     'mobileScoreDisplay': '695 rep, 100 pts',
#     'ordinal': 5,
#     'points': '100',
#     'rank': '1',
#     'scoreDisplay': '695 rep',
#     'scoreIdentifier': '0000',
#     'time': '695',
#     'workoutrank': '1',
#     'workoutresult': '--'},
#    {'breakdown': '25 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 2,
#     'location': '',
#     'mobileScoreDisplay': '5 pt, 25 pts',
#     'ordinal': 6,
#     'points': '25',
#     'rank': '16',
#     'scoreDisplay': '5 pt',
#     'scoreIdentifier': '0000',
#     'time': '5',
#     'workoutrank': '16',
#     'workoutresult': '--'},
#    {'breakdown': '90 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 7,
#     'location': '',
#     'mobileScoreDisplay': '14:34.71, 90 pts',
#     'ordinal': 7,
#     'points': '90',
#     'rank': '2',
#     'scoreDisplay': '14:34.71',
#     'scoreIdentifier': '0000',
#     'time': '14:34.71',
#     'workoutrank': '2',
#     'workoutresult': '--'},
#    {'breakdown': '30 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 7,
#     'location': '',
#     'mobileScoreDisplay': '0.0 lb, 30 pts',
#     'ordinal': 8,
#     'points': '30',
#     'rank': '8',
#     'scoreDisplay': '0.0 lb',
#     'scoreIdentifier': '0000',
#     'time': '.0',
#     'workoutrank': '8',
#     'workoutresult': '--'},
#    {'breakdown': '40 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 4,
#     'location': '',
#     'mobileScoreDisplay': '31:34.67, 40 pts',
#     'ordinal': 9,
#     'points': '40',
#     'rank': '7',
#     'scoreDisplay': '31:34.67',
#     'scoreIdentifier': '0000',
#     'time': '31:34.67',
#     'workoutrank': '7',
#     'workoutresult': '--'},
#    {'breakdown': '40 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 5,
#     'location': '',
#     'mobileScoreDisplay': '5:54.13, 40 pts',
#     'ordinal': 10,
#     'points': '40',
#     'rank': '7',
#     'scoreDisplay': '5:54.13',
#     'scoreIdentifier': '0000',
#     'time': '5:54.13',
#     'workoutrank': '7',
#     'workoutresult': '--'},
#    {'breakdown': '10 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 5,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+8, 10 pts',
#     'ordinal': 11,
#     'points': '10',
#     'rank': '10',
#     'scoreDisplay': 'CAP+8',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+8',
#     'workoutrank': '10',
#     'workoutresult': '--'},
#    {'breakdown': '60 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 2,
#     'location': '',
#     'mobileScoreDisplay': '9:47.12, 60 pts',
#     'ordinal': 12,
#     'points': '60',
#     'rank': '5',
#     'scoreDisplay': '9:47.12',
#     'scoreIdentifier': '0000',
#     'time': '9:47.12',
#     'workoutrank': '5',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44632,
#    'affiliateName': 'CrossFit Mayhem',
#    'age': 18,
#    'bibId': '116',
#    'competitorId': 671666,
#    'competitorName': 'Haley Adams',
#    'countryCode': None,
#    'countryOfOriginCode': 'US',
#    'countryOfOriginName': 'United States',
#    'divisionId': '02',
#    'firstName': 'Haley',
#    'gender': 'F',
#    'height': '5\'6"',
#    'lastName': 'Adams',
#    'profession': 0,
#    'profilePicS3key': '4c00e-P671666_8-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'ACT',
#    'teamCaptain': 0,
#    'weight': '143 lbs'},
#   'overallRank': '6',
#   'overallScore': '711',
#   'scores': [{'breakdown': '94 pts',
#     'exists': True,
#     'heat': 3,
#     'judge': '',
#     'lane': 12,
#     'location': '',
#     'mobileScoreDisplay': '19:00.73, 94 pts',
#     'ordinal': 1,
#     'points': '94',
#     'rank': '4',
#     'scoreDisplay': '19:00.73',
#     'scoreIdentifier': '0000',
#     'time': '19:00.73',
#     'workoutrank': '4',
#     'workoutresult': '--'},
#    {'breakdown': '66 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 22,
#     'location': '',
#     'mobileScoreDisplay': '7:20.43, 66 pts',
#     'ordinal': 2,
#     'points': '66',
#     'rank': '18',
#     'scoreDisplay': '7:20.43',
#     'scoreIdentifier': '0000',
#     'time': '7:20.43',
#     'workoutrank': '18',
#     'workoutresult': '--'},
#    {'breakdown': '90 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 28,
#     'location': '',
#     'mobileScoreDisplay': '28:34.89, 90 pts',
#     'ordinal': 3,
#     'points': '90',
#     'rank': '6',
#     'scoreDisplay': '28:34.89',
#     'scoreIdentifier': '0000',
#     'time': '28:34.89',
#     'workoutrank': '6',
#     'workoutresult': '--'},
#    {'breakdown': '14 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 12,
#     'location': '',
#     'mobileScoreDisplay': '2:28.77, 14 pts',
#     'ordinal': 4,
#     'points': '14',
#     'rank': '34',
#     'scoreDisplay': '2:28.77',
#     'scoreIdentifier': '0000',
#     'time': '2:28.77',
#     'workoutrank': '34',
#     'workoutresult': '--'},
#    {'breakdown': '72 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 15,
#     'location': '',
#     'mobileScoreDisplay': '605 rep, 72 pts',
#     'ordinal': 5,
#     'points': '72',
#     'rank': '8',
#     'scoreDisplay': '605 rep',
#     'scoreIdentifier': '0000',
#     'time': '605',
#     'workoutrank': '8',
#     'workoutresult': '--'},
#    {'breakdown': '75 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 9,
#     'location': '',
#     'mobileScoreDisplay': '15 pt, 75 pts',
#     'ordinal': 6,
#     'points': '75',
#     'rank': '6',
#     'scoreDisplay': '15 pt',
#     'scoreIdentifier': '0000',
#     'time': '15',
#     'workoutrank': '6',
#     'workoutresult': '--'},
#    {'breakdown': '50 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 3,
#     'location': '',
#     'mobileScoreDisplay': '17:28.35, 50 pts',
#     'ordinal': 7,
#     'points': '50',
#     'rank': '6',
#     'scoreDisplay': '17:28.35',
#     'scoreIdentifier': '0000',
#     'time': '17:28.35',
#     'workoutrank': '6',
#     'workoutresult': '--'},
#    {'breakdown': '10 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 5,
#     'location': '',
#     'mobileScoreDisplay': '0.0 lb, 10 pts',
#     'ordinal': 8,
#     'points': '10',
#     'rank': '10',
#     'scoreDisplay': '0.0 lb',
#     'scoreIdentifier': '0000',
#     'time': '.0',
#     'workoutrank': '10',
#     'workoutresult': '--'},
#    {'breakdown': '90 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 8,
#     'location': '',
#     'mobileScoreDisplay': '28:18.50, 90 pts',
#     'ordinal': 9,
#     'points': '90',
#     'rank': '2',
#     'scoreDisplay': '28:18.50',
#     'scoreIdentifier': '0000',
#     'time': '28:18.50',
#     'workoutrank': '2',
#     'workoutresult': '--'},
#    {'breakdown': '60 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 3,
#     'location': '',
#     'mobileScoreDisplay': '5:45.49, 60 pts',
#     'ordinal': 10,
#     'points': '60',
#     'rank': '5',
#     'scoreDisplay': '5:45.49',
#     'scoreIdentifier': '0000',
#     'time': '5:45.49',
#     'workoutrank': '5',
#     'workoutresult': '--'},
#    {'breakdown': '60 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 3,
#     'location': '',
#     'mobileScoreDisplay': '3:33.52, 60 pts',
#     'ordinal': 11,
#     'points': '60',
#     'rank': '5',
#     'scoreDisplay': '3:33.52',
#     'scoreIdentifier': '0000',
#     'time': '3:33.52',
#     'workoutrank': '5',
#     'workoutresult': '--'},
#    {'breakdown': '30 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 3,
#     'location': '',
#     'mobileScoreDisplay': '10:40.00, 30 pts',
#     'ordinal': 12,
#     'points': '30',
#     'rank': '8',
#     'scoreDisplay': '10:40.00',
#     'scoreIdentifier': '0000',
#     'time': '10:40.00',
#     'workoutrank': '8',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44601,
#    'affiliateName': 'Centerville CrossFit',
#    'age': 27,
#    'bibId': '104',
#    'competitorId': 174547,
#    'competitorName': 'Amanda Barnhart',
#    'countryCode': None,
#    'countryOfOriginCode': 'US',
#    'countryOfOriginName': 'United States',
#    'divisionId': '02',
#    'firstName': 'Amanda',
#    'gender': 'F',
#    'height': '5\'7"',
#    'lastName': 'Barnhart',
#    'profession': 0,
#    'profilePicS3key': '95b3d-P174547_7-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'ACT',
#    'teamCaptain': 0,
#    'weight': '155 lbs'},
#   'overallRank': '7',
#   'overallScore': '706',
#   'scores': [{'breakdown': '64 pts',
#     'exists': True,
#     'heat': 3,
#     'judge': '',
#     'lane': 30,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+9, 64 pts',
#     'ordinal': 1,
#     'points': '64',
#     'rank': '19',
#     'scoreDisplay': 'CAP+9',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+9',
#     'workoutrank': '19',
#     'workoutresult': '--'},
#    {'breakdown': '94 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 11,
#     'location': '',
#     'mobileScoreDisplay': '6:37.00, 94 pts',
#     'ordinal': 2,
#     'points': '94',
#     'rank': '4',
#     'scoreDisplay': '6:37.00',
#     'scoreIdentifier': '0000',
#     'time': '6:37.00',
#     'workoutrank': '4',
#     'workoutresult': '--'},
#    {'breakdown': '72 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 29,
#     'location': '',
#     'mobileScoreDisplay': '29:30.45, 72 pts',
#     'ordinal': 3,
#     'points': '72',
#     'rank': '15',
#     'scoreDisplay': '29:30.45',
#     'scoreIdentifier': '0000',
#     'time': '29:30.45',
#     'workoutrank': '15',
#     'workoutresult': '--'},
#    {'breakdown': '100 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 7,
#     'location': '',
#     'mobileScoreDisplay': '1:29.08, 100 pts',
#     'ordinal': 4,
#     'points': '100',
#     'rank': '1',
#     'scoreDisplay': '1:29.08',
#     'scoreIdentifier': '0000',
#     'time': '1:29.08',
#     'workoutrank': '1',
#     'workoutresult': '--'},
#    {'breakdown': '16 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 9,
#     'location': '',
#     'mobileScoreDisplay': '486 rep, 16 pts',
#     'ordinal': 5,
#     'points': '16',
#     'rank': '25',
#     'scoreDisplay': '486 rep',
#     'scoreIdentifier': '0000',
#     'time': '486',
#     'workoutrank': '25',
#     'workoutresult': '--'},
#    {'breakdown': '30 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 6,
#     'location': '',
#     'mobileScoreDisplay': '6 pt, 30 pts',
#     'ordinal': 6,
#     'points': '30',
#     'rank': '15',
#     'scoreDisplay': '6 pt',
#     'scoreIdentifier': '0000',
#     'time': '6',
#     'workoutrank': '15',
#     'workoutresult': '--'},
#    {'breakdown': '10 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 10,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+17, 10 pts',
#     'ordinal': 7,
#     'points': '10',
#     'rank': '10',
#     'scoreDisplay': 'CAP+17',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+17',
#     'workoutrank': '10',
#     'workoutresult': '--'},
#    {'breakdown': '90 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 1,
#     'location': '',
#     'mobileScoreDisplay': '260.0 lb, 90 pts',
#     'ordinal': 8,
#     'points': '90',
#     'rank': '2',
#     'scoreDisplay': '260.0 lb',
#     'scoreIdentifier': '0000',
#     'time': '260.0',
#     'workoutrank': '2',
#     'workoutresult': '--'},
#    {'breakdown': '60 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 7,
#     'location': '',
#     'mobileScoreDisplay': '28:32.52, 60 pts',
#     'ordinal': 9,
#     'points': '60',
#     'rank': '5',
#     'scoreDisplay': '28:32.52',
#     'scoreIdentifier': '0000',
#     'time': '28:32.52',
#     'workoutrank': '5',
#     'workoutresult': '--'},
#    {'breakdown': '30 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 2,
#     'location': '',
#     'mobileScoreDisplay': '6:00.45, 30 pts',
#     'ordinal': 10,
#     'points': '30',
#     'rank': '8',
#     'scoreDisplay': '6:00.45',
#     'scoreIdentifier': '0000',
#     'time': '6:00.45',
#     'workoutrank': '8',
#     'workoutresult': '--'},
#    {'breakdown': '90 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 2,
#     'location': '',
#     'mobileScoreDisplay': '3:06.76, 90 pts',
#     'ordinal': 11,
#     'points': '90',
#     'rank': '2',
#     'scoreDisplay': '3:06.76',
#     'scoreIdentifier': '0000',
#     'time': '3:06.76',
#     'workoutrank': '2',
#     'workoutresult': '--'},
#    {'breakdown': '50 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 8,
#     'location': '',
#     'mobileScoreDisplay': '10:04.82, 50 pts',
#     'ordinal': 12,
#     'points': '50',
#     'rank': '6',
#     'scoreDisplay': '10:04.82',
#     'scoreIdentifier': '0000',
#     'time': '10:04.82',
#     'workoutrank': '6',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44951,
#    'affiliateName': 'Streamline CrossFit',
#    'age': 25,
#    'bibId': '301',
#    'competitorId': 592472,
#    'competitorName': 'Bethany Shadburne',
#    'countryCode': None,
#    'countryOfOriginCode': 'US',
#    'countryOfOriginName': 'United States',
#    'divisionId': '02',
#    'firstName': 'Bethany',
#    'gender': 'F',
#    'height': '5\'4"',
#    'lastName': 'Shadburne',
#    'profession': 0,
#    'profilePicS3key': '69340-P592472_6-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'ACT',
#    'teamCaptain': 0,
#    'weight': '145 lbs'},
#   'overallRank': '8',
#   'overallScore': '659',
#   'scores': [{'breakdown': '78 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 22,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+8, 78 pts',
#     'ordinal': 1,
#     'points': '78',
#     'rank': '12',
#     'scoreDisplay': 'CAP+8',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+8',
#     'workoutrank': '12',
#     'workoutresult': '--'},
#    {'breakdown': '30 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 26,
#     'location': '',
#     'mobileScoreDisplay': '8:55.25, 30 pts',
#     'ordinal': 2,
#     'points': '30',
#     'rank': '45',
#     'scoreDisplay': '8:55.25',
#     'scoreIdentifier': '0000',
#     'time': '8:55.25',
#     'workoutrank': '45',
#     'workoutresult': '--'},
#    {'breakdown': '86 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 14,
#     'location': '',
#     'mobileScoreDisplay': '28:43.07, 86 pts',
#     'ordinal': 3,
#     'points': '86',
#     'rank': '8',
#     'scoreDisplay': '28:43.07',
#     'scoreIdentifier': '0000',
#     'time': '28:43.07',
#     'workoutrank': '8',
#     'workoutresult': '--'},
#    {'breakdown': '70 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 18,
#     'location': '',
#     'mobileScoreDisplay': '1:47.02, 70 pts',
#     'ordinal': 4,
#     'points': '70',
#     'rank': '11',
#     'scoreDisplay': '1:47.02',
#     'scoreIdentifier': '0000',
#     'time': '1:47.02',
#     'workoutrank': '11',
#     'workoutresult': '--'},
#    {'breakdown': '80 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 8,
#     'location': '',
#     'mobileScoreDisplay': '609 rep, 80 pts',
#     'ordinal': 5,
#     'points': '80',
#     'rank': '6',
#     'scoreDisplay': '609 rep',
#     'scoreIdentifier': '0000',
#     'time': '609',
#     'workoutrank': '6',
#     'workoutresult': '--'},
#    {'breakdown': '55 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 8,
#     'location': '',
#     'mobileScoreDisplay': '11 pt, 55 pts',
#     'ordinal': 6,
#     'points': '55',
#     'rank': '10',
#     'scoreDisplay': '11 pt',
#     'scoreIdentifier': '0000',
#     'time': '11',
#     'workoutrank': '10',
#     'workoutresult': '--'},
#    {'breakdown': '40 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 9,
#     'location': '',
#     'mobileScoreDisplay': '17:54.87, 40 pts',
#     'ordinal': 7,
#     'points': '40',
#     'rank': '7',
#     'scoreDisplay': '17:54.87',
#     'scoreIdentifier': '0000',
#     'time': '17:54.87',
#     'workoutrank': '7',
#     'workoutresult': '--'},
#    {'breakdown': '20 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 4,
#     'location': '',
#     'mobileScoreDisplay': '0.0 lb, 20 pts',
#     'ordinal': 8,
#     'points': '20',
#     'rank': '9',
#     'scoreDisplay': '0.0 lb',
#     'scoreIdentifier': '0000',
#     'time': '.0',
#     'workoutrank': '9',
#     'workoutresult': '--'},
#    {'breakdown': '80 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 10,
#     'location': '',
#     'mobileScoreDisplay': '28:26.58, 80 pts',
#     'ordinal': 9,
#     'points': '80',
#     'rank': '3',
#     'scoreDisplay': '28:26.58',
#     'scoreIdentifier': '0000',
#     'time': '28:26.58',
#     'workoutrank': '3',
#     'workoutresult': '--'},
#    {'breakdown': '90 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 4,
#     'location': '',
#     'mobileScoreDisplay': '5:38.21, 90 pts',
#     'ordinal': 10,
#     'points': '90',
#     'rank': '2',
#     'scoreDisplay': '5:38.21',
#     'scoreIdentifier': '0000',
#     'time': '5:38.21',
#     'workoutrank': '2',
#     'workoutresult': '--'},
#    {'breakdown': '20 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 4,
#     'location': '',
#     'mobileScoreDisplay': '3:59.96, 20 pts',
#     'ordinal': 11,
#     'points': '20',
#     'rank': '9',
#     'scoreDisplay': '3:59.96',
#     'scoreIdentifier': '0000',
#     'time': '3:59.96',
#     'workoutrank': '9',
#     'workoutresult': '--'},
#    {'breakdown': '10 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 9,
#     'location': '',
#     'mobileScoreDisplay': '10:57.10, 10 pts',
#     'ordinal': 12,
#     'points': '10',
#     'rank': '10',
#     'scoreDisplay': '10:57.10',
#     'scoreIdentifier': '0000',
#     'time': '10:57.10',
#     'workoutrank': '10',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44717,
#    'affiliateName': 'CrossFit Kallithea',
#    'age': 29,
#    'bibId': '167',
#    'competitorId': 252900,
#    'competitorName': 'Anna Fragkou',
#    'countryCode': None,
#    'countryOfOriginCode': 'GR',
#    'countryOfOriginName': 'Greece',
#    'divisionId': '02',
#    'firstName': 'Anna',
#    'gender': 'F',
#    'height': '5\'3"',
#    'lastName': 'Fragkou',
#    'profession': 0,
#    'profilePicS3key': '5b3c7-P252900_1-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'DQ',
#    'teamCaptain': 0,
#    'weight': '139 lbs'},
#   'overallRank': 'DQ',
#   'overallScore': '640',
#   'scores': [{'breakdown': '80 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 43,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+8, 80 pts',
#     'ordinal': 1,
#     'points': '80',
#     'rank': '11',
#     'scoreDisplay': 'CAP+8',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+8',
#     'workoutrank': '11',
#     'workoutresult': '--'},
#    {'breakdown': '50 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 15,
#     'location': '',
#     'mobileScoreDisplay': '7:49.58, 50 pts',
#     'ordinal': 2,
#     'points': '50',
#     'rank': '26',
#     'scoreDisplay': '7:49.58',
#     'scoreIdentifier': '0000',
#     'time': '7:49.58',
#     'workoutrank': '26',
#     'workoutresult': '--'},
#    {'breakdown': '56 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 34,
#     'location': '',
#     'mobileScoreDisplay': '30:47.20, 56 pts',
#     'ordinal': 3,
#     'points': '56',
#     'rank': '23',
#     'scoreDisplay': '30:47.20',
#     'scoreIdentifier': '0000',
#     'time': '30:47.20',
#     'workoutrank': '23',
#     'workoutresult': '--'},
#    {'breakdown': '85 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 1,
#     'location': '',
#     'mobileScoreDisplay': '1:41.85, 85 pts',
#     'ordinal': 4,
#     'points': '85',
#     'rank': '6',
#     'scoreDisplay': '1:41.85',
#     'scoreIdentifier': '0000',
#     'time': '1:41.85',
#     'workoutrank': '6',
#     'workoutresult': '--'},
#    {'breakdown': '84 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 13,
#     'location': '',
#     'mobileScoreDisplay': '627 rep, 84 pts',
#     'ordinal': 5,
#     'points': '84',
#     'rank': '5',
#     'scoreDisplay': '627 rep',
#     'scoreIdentifier': '0000',
#     'time': '627',
#     'workoutrank': '5',
#     'workoutresult': '--'},
#    {'breakdown': '45 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 5,
#     'location': '',
#     'mobileScoreDisplay': '9 pt, 45 pts',
#     'ordinal': 6,
#     'points': '45',
#     'rank': '12',
#     'scoreDisplay': '9 pt',
#     'scoreIdentifier': '0000',
#     'time': '9',
#     'workoutrank': '12',
#     'workoutresult': '--'},
#    {'breakdown': '20 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 2,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+10, 20 pts',
#     'ordinal': 7,
#     'points': '20',
#     'rank': '9',
#     'scoreDisplay': 'CAP+10',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+10',
#     'workoutrank': '9',
#     'workoutresult': '--'},
#    {'breakdown': '80 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 2,
#     'location': '',
#     'mobileScoreDisplay': '230.0 lb, 80 pts',
#     'ordinal': 8,
#     'points': '80',
#     'rank': '3',
#     'scoreDisplay': '230.0 lb',
#     'scoreIdentifier': '0000',
#     'time': '230.0',
#     'workoutrank': '3',
#     'workoutresult': '--'},
#    {'breakdown': '10 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 6,
#     'location': '',
#     'mobileScoreDisplay': '38:58.31, 10 pts',
#     'ordinal': 9,
#     'points': '10',
#     'rank': '10',
#     'scoreDisplay': '38:58.31',
#     'scoreIdentifier': '0000',
#     'time': '38:58.31',
#     'workoutrank': '10',
#     'workoutresult': '--'},
#    {'breakdown': '20 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 5,
#     'location': '',
#     'mobileScoreDisplay': '6:11.82, 20 pts',
#     'ordinal': 10,
#     'points': '20',
#     'rank': '9',
#     'scoreDisplay': '6:11.82',
#     'scoreIdentifier': '0000',
#     'time': '6:11.82',
#     'workoutrank': '9',
#     'workoutresult': '--'},
#    {'breakdown': '30 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 5,
#     'location': '',
#     'mobileScoreDisplay': '3:59.06, 30 pts',
#     'ordinal': 11,
#     'points': '30',
#     'rank': '8',
#     'scoreDisplay': '3:59.06',
#     'scoreIdentifier': '0000',
#     'time': '3:59.06',
#     'workoutrank': '8',
#     'workoutresult': '--'},
#    {'breakdown': '80 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 10,
#     'location': '',
#     'mobileScoreDisplay': '9:34.27, 80 pts',
#     'ordinal': 12,
#     'points': '80',
#     'rank': '3',
#     'scoreDisplay': '9:34.27',
#     'scoreIdentifier': '0000',
#     'time': '9:34.27',
#     'workoutrank': '3',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44952,
#    'affiliateName': 'CrossFit Zug',
#    'age': 27,
#    'bibId': '119',
#    'competitorId': 19501,
#    'competitorName': 'Thuridur Erla Helgadottir',
#    'countryCode': None,
#    'countryOfOriginCode': 'IS',
#    'countryOfOriginName': 'Iceland',
#    'divisionId': '02',
#    'firstName': 'Thuridur Erla',
#    'gender': 'F',
#    'height': '5\'5"',
#    'lastName': 'Helgadottir',
#    'profession': 0,
#    'profilePicS3key': '4641e-P19501_6-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'ACT',
#    'teamCaptain': 0,
#    'weight': '130 lbs'},
#   'overallRank': '9',
#   'overallScore': '611',
#   'scores': [{'breakdown': '74 pts',
#     'exists': True,
#     'heat': 3,
#     'judge': '',
#     'lane': 10,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+8, 74 pts',
#     'ordinal': 1,
#     'points': '74',
#     'rank': '14',
#     'scoreDisplay': 'CAP+8',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+8',
#     'workoutrank': '14',
#     'workoutresult': '--'},
#    {'breakdown': '60 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 27,
#     'location': '',
#     'mobileScoreDisplay': '7:28.44, 60 pts',
#     'ordinal': 2,
#     'points': '60',
#     'rank': '21',
#     'scoreDisplay': '7:28.44',
#     'scoreIdentifier': '0000',
#     'time': '7:28.44',
#     'workoutrank': '21',
#     'workoutresult': '--'},
#    {'breakdown': '54 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 33,
#     'location': '',
#     'mobileScoreDisplay': '30:51.60, 54 pts',
#     'ordinal': 3,
#     'points': '54',
#     'rank': '24',
#     'scoreDisplay': '30:51.60',
#     'scoreIdentifier': '0000',
#     'time': '30:51.60',
#     'workoutrank': '24',
#     'workoutresult': '--'},
#    {'breakdown': '79 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 2,
#     'location': '',
#     'mobileScoreDisplay': '1:45.23, 79 pts',
#     'ordinal': 4,
#     'points': '79',
#     'rank': '8',
#     'scoreDisplay': '1:45.23',
#     'scoreIdentifier': '0000',
#     'time': '1:45.23',
#     'workoutrank': '8',
#     'workoutresult': '--'},
#    {'breakdown': '49 pts',
#     'exists': True,
#     'heat': 2,
#     'judge': '',
#     'lane': 14,
#     'location': '',
#     'mobileScoreDisplay': '574 rep, 49 pts',
#     'ordinal': 5,
#     'points': '49',
#     'rank': '14',
#     'scoreDisplay': '574 rep',
#     'scoreIdentifier': '0000',
#     'time': '574',
#     'workoutrank': '14',
#     'workoutresult': '--'},
#    {'breakdown': '85 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 12,
#     'location': '',
#     'mobileScoreDisplay': '17 pt, 85 pts',
#     'ordinal': 6,
#     'points': '85',
#     'rank': '4',
#     'scoreDisplay': '17 pt',
#     'scoreIdentifier': '0000',
#     'time': '17',
#     'workoutrank': '4',
#     'workoutresult': '--'},
#    {'breakdown': '30 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 8,
#     'location': '',
#     'mobileScoreDisplay': '19:21.03, 30 pts',
#     'ordinal': 7,
#     'points': '30',
#     'rank': '8',
#     'scoreDisplay': '19:21.03',
#     'scoreIdentifier': '0000',
#     'time': '19:21.03',
# ...
#   'entrant': {'affiliateId': 44721,
#    'affiliateName': 'La Borda CrossFit',
#    'age': 25,
#    'bibId': '208',
#    'competitorId': 1243131,
#    'competitorName': 'Miriam Torra Sola',
#    'countryCode': None,
#    'countryOfOriginCode': 'AD',
#    'countryOfOriginName': 'Andorra',
#    'divisionId': '02',
#    'firstName': 'Miriam',
#    'gender': 'F',
#    'height': '5\'7"',
#    'lastName': 'Torra',
#    'profession': 0,
#    'profilePicS3key': '996b1-P1243131_3-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'CUT',
#    'teamCaptain': 0,
#    'weight': '141 lbs'},
#   'overallRank': '126',
#   'overallScore': '-42',
#   'scores': [{'breakdown': '-42 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 40,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+43, -42 pts',
#     'ordinal': 1,
#     'points': '-42',
#     'rank': '117T',
#     'scoreDisplay': 'CAP+43',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+43',
#     'workoutrank': '117T',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 2,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 3,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 4,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 5,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 6,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 7,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 8,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 9,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 10,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 11,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 12,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'age': 23,
#    'bibId': '188',
#    'competitorId': 1521928,
#    'competitorName': 'Tamara Trumbetaš',
#    'countryCode': None,
#    'countryOfOriginCode': 'RS',
#    'countryOfOriginName': 'Serbia',
#    'divisionId': '02',
#    'firstName': 'Tamara',
#    'gender': 'F',
#    'height': '5\'4"',
#    'lastName': 'Trumbetaš',
#    'profession': 0,
#    'profilePicS3key': '3fad6-P1521928_2-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'CUT',
#    'teamCaptain': 0,
#    'weight': '143 lbs'},
#   'overallRank': '127',
#   'overallScore': '-42',
#   'scores': [{'breakdown': '-42 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 31,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+43, -42 pts',
#     'ordinal': 1,
#     'points': '-42',
#     'rank': '117T',
#     'scoreDisplay': 'CAP+43',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+43',
#     'workoutrank': '117T',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 2,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 3,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 4,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 5,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 6,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 7,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 8,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 9,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 10,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 11,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 12,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44728,
#    'affiliateName': 'CrossFit Ceylon',
#    'age': 22,
#    'bibId': '214',
#    'competitorId': 661943,
#    'competitorName': 'Keshini Vitharana',
#    'countryCode': None,
#    'countryOfOriginCode': 'LK',
#    'countryOfOriginName': 'Sri Lanka',
#    'divisionId': '02',
#    'firstName': 'Keshini',
#    'gender': 'F',
#    'height': '0\'5"',
#    'lastName': 'Vitharana',
#    'profession': 0,
#    'profilePicS3key': '823ae-P661943_1-184.jpg',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'CUT',
#    'teamCaptain': 0,
#    'weight': '130 lbs'},
#   'overallRank': '128',
#   'overallScore': '-42',
#   'scores': [{'breakdown': '-42 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 42,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+43, -42 pts',
#     'ordinal': 1,
#     'points': '-42',
#     'rank': '117T',
#     'scoreDisplay': 'CAP+43',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+43',
#     'workoutrank': '117T',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 2,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 3,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 4,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 5,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 6,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 7,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 8,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 9,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 10,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 11,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 12,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}},
#  {'cf_rank_order': '',
#   'entrant': {'affiliateId': 44635,
#    'affiliateName': 'UPT CrossFit',
#    'age': 33,
#    'bibId': '218',
#    'competitorId': 889971,
#    'competitorName': 'Melanie Yip Woon Sun',
#    'countryCode': None,
#    'countryOfOriginCode': 'MU',
#    'countryOfOriginName': 'Mauritius',
#    'divisionId': '02',
#    'firstName': 'Melanie',
#    'gender': 'F',
#    'height': '5\'5"',
#    'lastName': 'Yip Woon Sun',
#    'profession': 0,
#    'profilePicS3key': 'pukie.png',
#    'regionCode': '',
#    'regionId': '0',
#    'regionName': '',
#    'regionalCode': '',
#    'status': 'CUT',
#    'teamCaptain': 0,
#    'weight': '170 lbs'},
#   'overallRank': '129',
#   'overallScore': '-42',
#   'scores': [{'breakdown': '-42 pts',
#     'exists': True,
#     'heat': 1,
#     'judge': '',
#     'lane': 44,
#     'location': '',
#     'mobileScoreDisplay': 'CAP+43, -42 pts',
#     'ordinal': 1,
#     'points': '-42',
#     'rank': '117T',
#     'scoreDisplay': 'CAP+43',
#     'scoreIdentifier': '0000',
#     'time': 'CAP+43',
#     'workoutrank': '117T',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 2,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 3,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 4,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 5,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 6,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 7,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 8,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 9,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 10,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 11,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'},
#    {'breakdown': '',
#     'exists': True,
#     'heat': 0,
#     'judge': '',
#     'lane': 0,
#     'location': '',
#     'ordinal': 12,
#     'points': 0,
#     'rank': 'CUT',
#     'scoreIdentifier': '0000',
#     'time': '',
#     'workoutrank': 'CUT',
#     'workoutresult': '--'}],
#   'ui': {'countryChampion': False, 'drawBlueHR': False, 'highlight': False}}]

# %%
database = []
for i in range(len(leaderboard)):
    competitors = leaderboard[i]['entrant']['competitorName']
    for j in range(len(leaderboard[i]['scores'])):
        workout_number = leaderboard[i]['scores'][j]['ordinal']
        times = leaderboard[i]['scores'][j]['time']
        ranks = leaderboard[i]['scores'][j]['rank']
        score = leaderboard[i]['scores'][j]['breakdown']
        database.append([competitors, workout_number, times, ranks, score])

# %%
full_data = pd.DataFrame(database, columns=['competitors', 'ordinals', 'times', 'ranks', 'score'])

# %%
full_data = full_data[(full_data.ranks != 'WD') 
                      & (full_data.ranks != 'CUT') 
                      & (full_data.ranks != 'DNF') 
                      & (full_data.ranks != '')]

# %% [markdown]
# # Event 1

# %%
event_1 = full_data[full_data['ordinals']==1].sort_values('times')
event_1
# Out:
#                       competitors  ordinals     times ranks    score
# 0                Tia-Clair Toomey         1  16:56.63     1  100 pts
# 48                 Karissa Pearce         1  18:16.35     2   98 pts
# 24                   Jamie Greene         1  19:00.67     3   96 pts
# 60                    Haley Adams         1  19:00.73     4   94 pts
# 288             Feeroozeh Saghafi         1       CAP     5   92 pts
# 132            Annie Thorisdottir         1     CAP+1     6   90 pts
# 360                 Paige Semenza         1    CAP+10    24   54 pts
# 312                  Dani Speegle         1    CAP+10    25   52 pts
# 528                Leonie Henrich         1    CAP+11    30   45 pts
# 396             Carole Castellani         1    CAP+11    31   44 pts
# 372                     Emma Tall         1    CAP+11    27   48 pts
# 540                Carmen Bosmans         1    CAP+11    34   41 pts
# 324                Colleen Fotsch         1    CAP+11    26   50 pts
# 564           Thelma Christoforou         1    CAP+11    28   47 pts
# 504                Ksenija Kecman         1    CAP+11    29   46 pts
# 516               Katie Trombetta         1    CAP+11    32   43 pts
# 144              Carolyne Prevost         1    CAP+11    33   42 pts
# 552          Jacqueline Dahlstrøm         1    CAP+12    35   40 pts
# 576          Carol Colling-Romero         1    CAP+13    36   39 pts
# 468                  Cheryl Nasso         1    CAP+16    37   38 pts
# 636                 Neyran Guneli         1    CAP+16    38   37 pts
# 300                Mekenzie Riley         1    CAP+17    39   36 pts
# 492               Michelle Merand         1    CAP+19    45   30 pts
# 444                Hanna Karlsson         1    CAP+19    42   33 pts
# 420           Alessia Joy Wälchli         1    CAP+19    47   28 pts
# 408               Lindsay Vaughan         1    CAP+19    43   32 pts
# 384                 Carrie Beamer         1    CAP+19    41   34 pts
# 336   Camilla Salomonsson Hellman         1    CAP+19    44   31 pts
# 624             Anastasiya Ganina         1    CAP+19    48   27 pts
# 672               Emilia Leppanen         1    CAP+19    46   29 pts
# ...                           ...       ...       ...   ...      ...
# 1404              Dema Al Zebdieh         1    CAP+43  117T  -42 pts
# 1416              Amal Alshahrani         1    CAP+43  117T  -42 pts
# 1428                  Zaida Amade         1    CAP+43  117T  -42 pts
# 1440              MariaNive Clark         1    CAP+43  117T  -42 pts
# 1536             Tamara Trumbetaš         1    CAP+43  117T  -42 pts
# 1476              Chanelle Munroe         1    CAP+43  117T  -42 pts
# 1488                 Mishka Murad         1    CAP+43  117T  -42 pts
# 1500                 Trang Nguyen         1    CAP+43  117T  -42 pts
# 1512           Cingiwe Ciegy Seru         1    CAP+43  117T  -42 pts
# 1524            Miriam Torra Sola         1    CAP+43  117T  -42 pts
# 1464              Krista Kraskura         1    CAP+43  117T  -42 pts
# 1452         Laura Gonzalez-Marin         1    CAP+43  117T  -42 pts
# 1560         Melanie Yip Woon Sun         1    CAP+43  117T  -42 pts
# 1548            Keshini Vitharana         1    CAP+43  117T  -42 pts
# 264                Madeline Sturt         1     CAP+6     9   84 pts
# 204               Samantha Briggs         1     CAP+6     8   86 pts
# 156           Alessandra Pichelli         1     CAP+7    10   82 pts
# 84              Bethany Shadburne         1     CAP+8    12   78 pts
# 96                   Anna Fragkou         1     CAP+8    11   80 pts
# 108     Thuridur Erla Helgadottir         1     CAP+8    14   74 pts
# 456        Oddrún Eik Gylfadottir         1     CAP+8    13   76 pts
# 240                  Emma McQuaid         1     CAP+8    15   72 pts
# 36      Katrin Tanja Davidsdottir         1     CAP+9    21   60 pts
# 276                   Meg Reardon         1     CAP+9    17   68 pts
# 168                 Laura Horvath         1     CAP+9    16   70 pts
# 180                  Brooke Wells         1     CAP+9    20   62 pts
# 120              Danielle Brandon         1     CAP+9    22   58 pts
# 72                Amanda Barnhart         1     CAP+9    19   64 pts
# 192     Carol-Ann Reason-Thibault         1     CAP+9    23   56 pts
# 348                Courtney Haley         1     CAP+9    18   66 pts
#
# [131 rows x 5 columns]

# %%
from datetime import datetime
total_seconds = []
for i, j in event_1.iterrows():
    if 'CAP' in j['times']:
        cap = 20*60
        if len(j['times'])==3:
            total_seconds.append(cap)
        else:
            total_seconds.append(cap+int(j['times'][4:]))
    else:
        datetime_convert = datetime.strptime(j['times'],'%M:%S.%f')

        total_seconds.append(datetime_convert.second + datetime_convert.minute*60 + datetime_convert.microsecond*1e-6)

# %%
event_1['total_seconds'] = total_seconds

lst = list(event_1['total_seconds']-min(event_1['total_seconds']))
event_1['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_1.sort_values('adjusted_score', ascending=False)
# Out:
#                     competitors  ordinals     times ranks    score  \
# 0              Tia-Clair Toomey         1  16:56.63     1  100 pts
# 48               Karissa Pearce         1  18:16.35     2   98 pts
# 24                 Jamie Greene         1  19:00.67     3   96 pts
# 60                  Haley Adams         1  19:00.73     4   94 pts
# 288           Feeroozeh Saghafi         1       CAP     5   92 pts
# 132          Annie Thorisdottir         1     CAP+1     6   90 pts
# 12                Kristin Holte         1     CAP+2     7   88 pts
# 264              Madeline Sturt         1     CAP+6     9   84 pts
# 204             Samantha Briggs         1     CAP+6     8   86 pts
# 156         Alessandra Pichelli         1     CAP+7    10   82 pts
# 108   Thuridur Erla Helgadottir         1     CAP+8    14   74 pts
# 84            Bethany Shadburne         1     CAP+8    12   78 pts
# 96                 Anna Fragkou         1     CAP+8    11   80 pts
# 244                    Emma McQuaid         5   546    18   37 pts
# 148                Carolyne Prevost         5   549   16T   43 pts
# 268                  Madeline Sturt         5   549   16T   43 pts
# 232  Ragnheiður Sara Sigmundsdottir         5   565    15   46 pts
# 112       Thuridur Erla Helgadottir         5   574    14   49 pts
# 196       Carol-Ann Reason-Thibault         5   584    13   52 pts
# 292               Feeroozeh Saghafi         5   586    12   56 pts
# 40        Katrin Tanja Davidsdottir         5   590    11   60 pts
# 136              Annie Thorisdottir         5   591    10   64 pts
# 208                 Samantha Briggs         5   598     9   68 pts
# 64                      Haley Adams         5   605     8   72 pts
# 184                    Brooke Wells         5   607     7   76 pts
# 88                Bethany Shadburne         5   609     6   80 pts
# 100                    Anna Fragkou         5   627     5   84 pts
# 4                  Tia-Clair Toomey         5   656     4   88 pts
# 28                     Jamie Greene         5   664     3   92 pts
# 16                    Kristin Holte         5   675     2   96 pts
# 52                   Karissa Pearce         5   695     1  100 pts

# %%
event_5['times'] = [int(i) for i in event_5['times']]
lst = list(event_5['times']-min(event_5['times']))
event_5['adjusted_score'] = [i*(100/max(lst)) for i in lst]

# %%
event_5.sort_values('adjusted_score', ascending=False)
# Out:
#                         competitors  ordinals  times ranks    score  \
# 52                   Karissa Pearce         5    695     1  100 pts
# 16                    Kristin Holte         5    675     2   96 pts
# 28                     Jamie Greene         5    664     3   92 pts
# 4                  Tia-Clair Toomey         5    656     4   88 pts
# 100                    Anna Fragkou         5    627     5   84 pts
# 88                Bethany Shadburne         5    609     6   80 pts
# 184                    Brooke Wells         5    607     7   76 pts
# 64                      Haley Adams         5    605     8   72 pts
# 208                 Samantha Briggs         5    598     9   68 pts
# 136              Annie Thorisdottir         5    591    10   64 pts
# 40        Katrin Tanja Davidsdottir         5    590    11   60 pts
# 292               Feeroozeh Saghafi         5    586    12   56 pts
# 196       Carol-Ann Reason-Thibault         5    584    13   52 pts
# 112       Thuridur Erla Helgadottir         5    574    14   49 pts
# 232  Ragnheiður Sara Sigmundsdottir         5    565    15   46 pts
# 268                  Madeline Sturt         5    549   16T   43 pts
# 148                Carolyne Prevost         5    549   16T   43 pts
# 244                    Emma McQuaid         5    546    18   37 pts
# 304                  Mekenzie Riley         5    545    19   34 pts
# 220                     Emily Rolfe         5    527    20   31 pts
# 160             Alessandra Pichelli         5    516    21   28 pts
# 280                     Meg Reardon         5    506    22   25 pts
# 256                   Karin Freyová         5    499    23   22 pts
# 124                Danielle Brandon         5    491    24   19 pts
# 76                  Amanda Barnhart         5    486    25   16 pts
# 352                  Courtney Haley         5    477    26   13 pts
# 172                   Laura Horvath         5    473    27   10 pts
# 316                    Dani Speegle         5    455    28    7 pts
# 340     Camilla Salomonsson Hellman         5    443    29    4 pts
# 328                  Colleen Fotsch         5    436    30    1 pts
#
#      adjusted_score
# 52           100.00
# 16            92.28
# 28            88.03
# 4             84.94
# 100           73.75
# 88            66.80
# 184           66.02
# 64            65.25
# 208           62.55
# 136           59.85
# 40            59.46
# 292           57.92
# 196           57.14
# 112           53.28
# 232           49.81
# 268           43.63
# 148           43.63
# 244           42.47
# 304           42.08
# 220           35.14
# 160           30.89
# 280           27.03
# 256           24.32
# 124           21.24
# 76            19.31
# 352           15.83
# 172           14.29
# 316            7.34
# 340            2.70
# 328            0.00

# %% [markdown]
# # Event 6

# %%
event_6 = full_data[full_data['ordinals']==6].sort_values('times')
event_6
# Out:
#                         competitors  ordinals times ranks    score
# 185                    Brooke Wells         6     1    20    5 pts
# 161             Alessandra Pichelli         6    10    11   50 pts
# 89                Bethany Shadburne         6    11    10   55 pts
# 41        Katrin Tanja Davidsdottir         6    12     9   60 pts
# 125                Danielle Brandon         6    13     8   65 pts
# 173                   Laura Horvath         6    14     7   70 pts
# 65                      Haley Adams         6    15     6   75 pts
# 29                     Jamie Greene         6    16     5   80 pts
# 113       Thuridur Erla Helgadottir         6    17     4   85 pts
# 5                  Tia-Clair Toomey         6    18     3   90 pts
# 149                Carolyne Prevost         6    19     2   95 pts
# 209                 Samantha Briggs         6     2    19   10 pts
# 17                    Kristin Holte         6    20     1  100 pts
# 221                     Emily Rolfe         6     3    18   15 pts
# 197       Carol-Ann Reason-Thibault         6     4    17   20 pts
# 53                   Karissa Pearce         6     5    16   25 pts
# 77                  Amanda Barnhart         6     6    15   30 pts
# 233  Ragnheiður Sara Sigmundsdottir         6     7    14   35 pts
# 137              Annie Thorisdottir         6     8    13   40 pts
# 101                    Anna Fragkou         6     9    12   45 pts

# %%
from datetime import datetime
total_seconds = []
for i, j in event_6.iterrows():
    if 'CAP' in j['times']:
        cap = 15*60
        if len(j['times'])==3:
            total_seconds.append(cap)
        else:
            total_seconds.append(cap+int(j['times'][4:]))
    else:
        try:
            datetime_convert = datetime.strptime(j['times'],':%S.%f')
        except:
            datetime_convert = datetime.strptime(j['times'],'%M')
        total_seconds.append(datetime_convert.second + datetime_convert.minute*60 + datetime_convert.microsecond*1e-6)

# %%
event_6['total_seconds'] = total_seconds

lst = list(event_6['total_seconds']-min(event_6['total_seconds']))
event_6['adjusted_score'] = [i*(100/max(lst)) for i in lst]

# %%
event_6.sort_values('adjusted_score', ascending=False)
# Out:
#                         competitors  ordinals times ranks    score  \
# 17                    Kristin Holte         6    20     1  100 pts
# 149                Carolyne Prevost         6    19     2   95 pts
# 5                  Tia-Clair Toomey         6    18     3   90 pts
# 113       Thuridur Erla Helgadottir         6    17     4   85 pts
# 29                     Jamie Greene         6    16     5   80 pts
# 65                      Haley Adams         6    15     6   75 pts
# 173                   Laura Horvath         6    14     7   70 pts
# 125                Danielle Brandon         6    13     8   65 pts
# 41        Katrin Tanja Davidsdottir         6    12     9   60 pts
# 89                Bethany Shadburne         6    11    10   55 pts
# 161             Alessandra Pichelli         6    10    11   50 pts
# 101                    Anna Fragkou         6     9    12   45 pts
# 137              Annie Thorisdottir         6     8    13   40 pts
# 233  Ragnheiður Sara Sigmundsdottir         6     7    14   35 pts
# 77                  Amanda Barnhart         6     6    15   30 pts
# 53                   Karissa Pearce         6     5    16   25 pts
# 197       Carol-Ann Reason-Thibault         6     4    17   20 pts
# 221                     Emily Rolfe         6     3    18   15 pts
# 209                 Samantha Briggs         6     2    19   10 pts
# 185                    Brooke Wells         6     1    20    5 pts
#
#      total_seconds  adjusted_score
# 17         1200.00          100.00
# 149        1140.00           94.74
# 5          1080.00           89.47
# 113        1020.00           84.21
# 29          960.00           78.95
# 65          900.00           73.68
# 173         840.00           68.42
# 125         780.00           63.16
# 41          720.00           57.89
# 89          660.00           52.63
# 161         600.00           47.37
# 101         540.00           42.11
# 137         480.00           36.84
# 233         420.00           31.58
# 77          360.00           26.32
# 53          300.00           21.05
# 197         240.00           15.79
# 221         180.00           10.53
# 209         120.00            5.26
# 185          60.00            0.00

# %% [markdown]
# # Top 10

# %%
frames = [event_1, event_2, event_3, event_4, event_5, event_6]
final_df = pd.concat(frames)[['competitors','adjusted_score', 'score']]
final_df['score'] = [int(i[:-4]) for i in final_df['score']
# 6                    15
# 7                    13
# 8                    11
# 9                     6
# 10                    8
# 11                   10
# 12                    9
# 13                   16
# 14                   12
# 15                   14
# 16                   17
# 17                   22
# 18                   19
# 19                   18
# 20                   21
# 21                   20
# 22                   24
# 23                   28
# 24                   27
# 25                   23
# 26                   25
# 27                   30
# 28                   26
# 29                   29
# ..                  ...
# 101                 107
# 102                 112
# 103                 104
# 104                 114
# 105                 109
# 106                 111
# 107                 106
# 108                 110
# 109                 102
# 110                 105
# 111                 108
# 112                 103
# 113                 116
# 114                 115
# 115                 113
# 116                 123
# 117                 124
# 118                 119
# 119                 131
# 120                 128
# 121                 127
# 122                 126
# 123                 118
# 124                 120
# 125                 117
# 126                 121
# 127                 130
# 128                 122
# 129                 125
# 130                 129
#
# [131 rows x 5 columns]

# %%
df.to_csv('Adjusted_Results/2019_Top_10_Women.csv')

# %% [markdown]
# # Event 7

# %%
event_7 = full_data[full_data['ordinals']==7].sort_values('times')

# %%
from datetime import datetime
total_seconds = []
for i, j in event_7.iterrows():
    if 'CAP' in j['times']:
        cap = 20*60
        if len(j['times'])==3:
            total_seconds.append(cap)
        else:
            total_seconds.append(cap+int(j['times'][4:]))
    else:
        datetime_convert = datetime.strptime(j['times'],'%M:%S.%f')
        total_seconds.append(datetime_convert.second + datetime_convert.minute*60 + datetime_convert.microsecond*1e-6)

# %%
event_7['total_seconds'] = total_seconds

lst = list(event_7['total_seconds']-min(event_7['total_seconds']))
event_7['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_7.sort_values('adjusted_score', ascending=False)
# Out:
#                    competitors  ordinals     times ranks    score  \
# 6             Tia-Clair Toomey         7  14:07.10     1  100 pts
# 54              Karissa Pearce         7  14:34.71     2   90 pts
# 42   Katrin Tanja Davidsdottir         7  15:10.09     3   80 pts
# 30                Jamie Greene         7  15:32.03     4   70 pts
# 18               Kristin Holte         7  16:10.92     5   60 pts
# 66                 Haley Adams         7  17:28.35     6   50 pts
# 90           Bethany Shadburne         7  17:54.87     7   40 pts
# 114  Thuridur Erla Helgadottir         7  19:21.03     8   30 pts
# 102               Anna Fragkou         7    CAP+10     9   20 pts
# 78             Amanda Barnhart         7    CAP+17    10   10 pts
#
#      total_seconds  adjusted_score
# 6           847.10          100.00
# 54          874.71           92.54
# 42          910.09           82.97
# 30          932.03           77.04
# 18          970.92           66.53
# 66         1048.35           45.59
# 90         1074.87           38.42
# 114        1161.03           15.13
# 102        1210.00            1.89
# 78         1217.00            0.00

# %% [markdown]
# # Event 8

# %%
event_8 = full_data[full_data['ordinals']==8].sort_values('times')
weight = []
for i, j in event_8.iterrows():
    if j['times'] == '.0':
        weight.append('215.0')
    else: 
        weight.append(j['times'])

event_8['times'] = weight

event_8
# Out:
#                    competitors  ordinals  times ranks    score
# 55              Karissa Pearce         8  215.0     8   30 pts
# 67                 Haley Adams         8  215.0    10   10 pts
# 91           Bethany Shadburne         8  215.0     9   20 pts
# 115  Thuridur Erla Helgadottir         8  215.0     7   40 pts
# 31                Jamie Greene         8  220.0     6   50 pts
# 19               Kristin Holte         8  225.0     5   60 pts
# 43   Katrin Tanja Davidsdottir         8  230.0     4   70 pts
# 103               Anna Fragkou         8  230.0     3   80 pts
# 79             Amanda Barnhart         8  260.0     2   90 pts
# 7             Tia-Clair Toomey         8  265.0     1  100 pts

# %%
event_8['times'] = [float(i) for i in event_8['times']]
lst = list(event_8['times']-min(event_8['times']))
event_8['adjusted_score'] = [i*(100/max(lst)) for i in lst]

# %%
event_8.sort_values('adjusted_score', ascending=False)
# Out:
#                    competitors  ordinals  times ranks    score  adjusted_score
# 7             Tia-Clair Toomey         8 265.00     1  100 pts          100.00
# 79             Amanda Barnhart         8 260.00     2   90 pts           90.00
# 43   Katrin Tanja Davidsdottir         8 230.00     4   70 pts           30.00
# 103               Anna Fragkou         8 230.00     3   80 pts           30.00
# 19               Kristin Holte         8 225.00     5   60 pts           20.00
# 31                Jamie Greene         8 220.00     6   50 pts           10.00
# 55              Karissa Pearce         8 215.00     8   30 pts            0.00
# 67                 Haley Adams         8 215.00    10   10 pts            0.00
# 91           Bethany Shadburne         8 215.00     9   20 pts            0.00
# 115  Thuridur Erla Helgadottir         8 215.00     7   40 pts            0.00

# %% [markdown]
# # Event 9

# %%
event_9 = full_data[full_data['ordinals']==9].sort_values('times')

# %%
from datetime import datetime
total_seconds = []
for i, j in event_9.iterrows():
    if 'CAP' in j['times']:
        cap = 50*60
        if len(j['times'])==3:
            total_seconds.append(cap)
        else:
            total_seconds.append(cap+int(j['times'][4:]))
    else:
        datetime_convert = datetime.strptime(j['times'],'%M:%S.%f')
        total_seconds.append(datetime_convert.second + datetime_convert.minute*60 + datetime_convert.microsecond*1e-6)

# %%
event_9['total_seconds'] = total_seconds

lst = list(event_9['total_seconds']-min(event_9['total_seconds']))
event_9['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_9.sort_values('adjusted_score', ascending=False)
# Out:
#                    competitors  ordinals     times ranks    score  \
# 8             Tia-Clair Toomey         9  25:12.25     1  100 pts
# 68                 Haley Adams         9  28:18.50     2   90 pts
# 92           Bethany Shadburne         9  28:26.58     3   80 pts
# 32                Jamie Greene         9  28:32.16     4   70 pts
# 80             Amanda Barnhart         9  28:32.52     5   60 pts
# 20               Kristin Holte         9  30:17.62     6   50 pts
# 56              Karissa Pearce         9  31:34.67     7   40 pts
# 44   Katrin Tanja Davidsdottir         9  32:36.98     8   30 pts
# 116  Thuridur Erla Helgadottir         9  32:42.99     9   20 pts
# 104               Anna Fragkou         9  38:58.31    10   10 pts
#
#      total_seconds  adjusted_score
# 8          1512.25          100.00
# 68         1698.50           77.45
# 92         1706.58           76.48
# 32         1712.16           75.80
# 80         1712.52           75.76
# 20         1817.62           63.03
# 56         1894.67           53.71
# 44         1956.98           46.16
# 116        1962.99           45.43
# 104        2338.31            0.00

# %% [markdown]
# # Event 10

# %%
event_10 = full_data[full_data['ordinals']==10].sort_values('times')

# %%
from datetime import datetime
total_seconds = []
for i, j in event_10.iterrows():
    if 'CAP' in j['times']:
        cap = 7*60
        if len(j['times'])==3:
            total_seconds.append(cap)
        else:
            total_seconds.append(cap+int(j['times'][4:]))
    else:
        datetime_convert = datetime.strptime(j['times'],'%M:%S.%f')
        total_seconds.append(datetime_convert.second + datetime_convert.minute*60)

# %%
event_10['total_seconds'] = total_seconds

lst = list(event_10['total_seconds']-min(event_10['total_seconds']))
event_10['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_10.sort_values('adjusted_score', ascending=False)
# Out:
#                    competitors  ordinals    times ranks    score  \
# 45   Katrin Tanja Davidsdottir        10  5:09.87     1  100 pts
# 93           Bethany Shadburne        10  5:38.21     2   90 pts
# 21               Kristin Holte        10  5:43.70     3   80 pts
# 9             Tia-Clair Toomey        10  5:44.63     4   70 pts
# 69                 Haley Adams        10  5:45.49     5   60 pts
# 33                Jamie Greene        10  5:52.21     6   50 pts
# 57              Karissa Pearce        10  5:54.13     7   40 pts
# 81             Amanda Barnhart        10  6:00.45     8   30 pts
# 105               Anna Fragkou        10  6:11.82     9   20 pts
# 117  Thuridur Erla Helgadottir        10      CAP    10   10 pts
#
#      total_seconds  adjusted_score
# 45             309          100.00
# 93             338           73.87
# 21             343           69.37
# 9              344           68.47
# 69             345           67.57
# 33             352           61.26
# 57             354           59.46
# 81             360           54.05
# 105            371           44.14
# 117            420            0.00

# %% [markdown]
# # Event 11

# %%
event_11 = full_data[full_data['ordinals']==11].sort_values('times')

# %%
from datetime import datetime
total_seconds = []
for i, j in event_11.iterrows():
    if 'CAP' in j['times']:
        cap = 5*60
        if len(j['times'])==3:
            total_seconds.append(cap)
        else:
            total_seconds.append(cap+int(j['times'][4:]))
    else:
        datetime_convert = datetime.strptime(j['times'],'%M:%S.%f')
        total_seconds.append(datetime_convert.second + datetime_convert.minute*60+datetime_convert.microsecond*1e-6)

# %%
event_11['total_seconds'] = total_seconds

lst = list(event_11['total_seconds']-min(event_11['total_seconds']))
event_11['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_11.sort_values('adjusted_score', ascending=False)
# Out:
#                    competitors  ordinals    times ranks    score  \
# 46   Katrin Tanja Davidsdottir        11  2:53.29     1  100 pts
# 82             Amanda Barnhart        11  3:06.76     2   90 pts
# 10            Tia-Clair Toomey        11  3:14.03     3   80 pts
# 118  Thuridur Erla Helgadottir        11  3:16.45     4   70 pts
# 70                 Haley Adams        11  3:33.52     5   60 pts
# 34                Jamie Greene        11  3:35.62     6   50 pts
# 22               Kristin Holte        11  3:49.14     7   40 pts
# 106               Anna Fragkou        11  3:59.06     8   30 pts
# 94           Bethany Shadburne        11  3:59.96     9   20 pts
# 58              Karissa Pearce        11    CAP+8    10   10 pts
#
#      total_seconds  adjusted_score
# 46          173.29          100.00
# 82          186.76           90.00
# 10          194.03           84.60
# 118         196.45           82.81
# 70          213.52           70.14
# 34          215.62           68.58
# 22          229.14           58.54
# 106         239.06           51.18
# 94          239.96           50.51
# 58          308.00            0.00

# %% [markdown]
# # Event 12

# %%
event_12 = full_data[full_data['ordinals']==12].sort_values('times')
event_12 = event_12[event_12.competitors != 'Will Moorad']

# %%
from datetime import datetime
total_seconds = []
for i, j in event_12.iterrows():
    if 'CAP' in j['times']:
        cap = 12*60
        if len(j['times'])==3:
            total_seconds.append(cap)
        else:
            total_seconds.append(cap+int(j['times'][4:]))
    else:
        datetime_convert = datetime.strptime(j['times'],'%M:%S.%f')
        total_seconds.append(datetime_convert.second + datetime_convert.minute*60+datetime_convert.microsecond*1e-6)

# %%
event_12['total_seconds'] = total_seconds

lst = list(event_12['total_seconds']-min(event_12['total_seconds']))
event_12['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_12.sort_values('adjusted_score', ascending=False)
# Out:
#                    competitors  ordinals     times ranks    score  \
# 11            Tia-Clair Toomey        12   8:25.09     1  100 pts
# 35                Jamie Greene        12   9:14.71     2   90 pts
# 107               Anna Fragkou        12   9:34.27     3   80 pts
# 23               Kristin Holte        12   9:38.26     4   70 pts
# 59              Karissa Pearce        12   9:47.12     5   60 pts
# 83             Amanda Barnhart        12  10:04.82     6   50 pts
# 119  Thuridur Erla Helgadottir        12  10:35.00     7   40 pts
# 71                 Haley Adams        12  10:40.00     8   30 pts
# 47   Katrin Tanja Davidsdottir        12  10:56.22     9   20 pts
# 95           Bethany Shadburne        12  10:57.10    10   10 pts
#
#      total_seconds  adjusted_score
# 11          505.09          100.00
# 35          554.71           67.36
# 107         574.27           54.49
# 23          578.26           51.87
# 59          587.12           46.04
# 83          604.82           34.39
# 119         635.00           14.54
# 71          640.00           11.25
# 47          656.22            0.58
# 95          657.10            0.00

# %% [markdown]
# # Final Analysis

# %%
frames = [event_1, event_2, event_3, event_4, event_5, event_6, event_7, event_8, event_9, event_10, event_11, event_12]
final_df = pd.concat(frames)[['competitors','adjusted_score', 'score']]
final_df['score'] = [int(i[:-4]) for i in final_df['score']]

adjusted_placements = final_df.groupby('competitors').agg({'adjusted_score':'sum','score':'sum'}).sort_values('adjusted_score', ascending=False)


adjusted_placements['adjusted_placement'] = [i+1 for i in range(len(adjusted_placements))]

actual_placement = []

for i in range(len(leaderboard)):
    competitors = leaderboard[i]['entrant']['competitorName']
    placement = leaderboard[i]['overallRank']
    actual_placement.append((competitors, placement))

final_placements = pd.DataFrame(actual_placement, columns=['competitors','actual_placement'])
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
df = final_placements.join(adjusted_placements, how='inner', on='competitors')
df = df[['competitors','score','actual_placement','adjusted_score','adjusted_placement']]

# %%
df
# Out:
#                         competitors  score actual_placement  adjusted_score  \
# 0                  Tia-Clair Toomey   1071                1         1033.46
# 1                     Kristin Holte    876                2          744.18
# 2                      Jamie Greene    851                3          755.60
# 3         Katrin Tanja Davidsdottir    784                4          682.51
# 4                    Karissa Pearce    714                5          639.60
# 5                       Haley Adams    711                6          620.15
# 6                   Amanda Barnhart    706                7          624.97
# 7                 Bethany Shadburne    659                8          524.10
# 8                      Anna Fragkou    640               DQ          487.88
# 9         Thuridur Erla Helgadottir    611                9          492.50
# 10                 Danielle Brandon    376               10          317.00
# 11               Annie Thorisdottir    370               11          308.68
# 12                 Carolyne Prevost    365               12          309.75
# 13              Alessandra Pichelli    365               13          280.66
# 14                    Laura Horvath    356               14          291.05
# 15                     Brooke Wells    351               15          281.42
# 16        Carol-Ann Reason-Thibault    328               16          276.20
# 17                  Samantha Briggs    318               17          217.32
# 18                      Emily Rolfe    317               18          261.52
# 19   Ragnheiður Sara Sigmundsdottir    294               19          269.90
# 20                     Emma McQuaid    255               20          221.15
# 21                    Karin Freyová    254               21          224.33
# 22                   Madeline Sturt    244               22          207.80
# 23                      Meg Reardon    243               23          191.99
# 24                Feeroozeh Saghafi    237               24          195.56
# 25                   Mekenzie Riley    228               25          209.75
# 26                     Dani Speegle    226               26          205.42
# 27                   Colleen Fotsch    222               27          187.82
# 28      Camilla Salomonsson Hellman    208               28          196.68
# 29                   Courtney Haley    191               29          190.11
# ..                              ...    ...              ...             ...
# 101                      Heidi Choi    -27              100            0.44
# 102              Landy Pui Boon Eng    -27              101            0.44
# 103                       Aya Fouad    -27              102            0.44
# 104              Victoria Frascolla    -27              103            0.44
# 105                    Alaa Hannora    -27              104            0.44
# 106                   Tsai-Jui Hung    -27              105            0.44
# 107                       Nina Juna    -27              106            0.44
# 108                    Sanaa Mandar    -27              107            0.44
# 109                   Sheena Miller    -27              108            0.44
# 110                  Gabriela Perez    -27              109            0.44
# 111                      Sara Pinto    -27              110            0.44
# 112                   Jessica Sanki    -27              111            0.44
# 113                Danielle Shanine    -27              112            0.44
# 114                     Vilija Teel    -27              113            0.44
# 115               Patricia Trujillo    -27              114            0.44
# 116                   Delice Adonis    -42              115            0.00
# 117                 Dema Al Zebdieh    -42              116            0.00
# 118                 Amal Alshahrani    -42              117            0.00
# 119                     Zaida Amade    -42              118            0.00
# 120                 MariaNive Clark    -42              119            0.00
# 121            Laura Gonzalez-Marin    -42              120            0.00
# 122                 Krista Kraskura    -42              121            0.00
# 123                 Chanelle Munroe    -42              122            0.00
# 124                    Mishka Murad    -42              123            0.00
# 125                    Trang Nguyen    -42              124            0.00
# 126              Cingiwe Ciegy Seru    -42              125            0.00
# 127               Miriam Torra Sola    -42              126            0.00
# 128                Tamara Trumbetaš    -42              127            0.00
# 129               Keshini Vitharana    -42              128            0.00
# 130            Melanie Yip Woon Sun    -42              129            0.00
#
#      adjusted_placement
# 0                     1
# 1                     3
# 2                     2
# 3                     4
# 4                     5
# 5                     7
# 6                     6
# 7                     8
# 8                    10
# 9                     9
# 10                   11
# 11                   13
# 12                   12
# 13                   16
# 14                   14
# 15                   15
# 16                   17
# 17                   22
# 18                   19
# 19                   18
# 20                   21
# 21                   20
# 22                   24
# 23                   28
# 24                   27
# 25                   23
# 26                   25
# 27                   30
# 28                   26
# 29                   29
# ..                  ...
# 101                 107
# 102                 112
# 103                 104
# 104                 114
# 105                 109
# 106                 111
# 107                 106
# 108                 110
# 109                 102
# 110                 105
# 111                 108
# 112                 103
# 113                 116
# 114                 115
# 115                 113
# 116                 123
# 117                 124
# 118                 119
# 119                 131
# 120                 128
# 121                 127
# 122                 126
# 123                 118
# 124                 120
# 125                 117
# 126                 121
# 127                 130
# 128                 122
# 129                 125
# 130                 129
#
# [131 rows x 5 columns]

# %%
df.to_csv('Adjusted_Results/Women_2019.csv')
