# %% [markdown]
# # All Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import json

with open('Men/2020_games.json') as f:
    data = json.load(f)
    
data.keys()
# Out:
# dict_keys(['sort', 'pagination', 'cachekey', 'dataType', 'competition', 'leaderboardRows', 'version', 'ordinals', 'totalPages', 'currentPage'])

# %%
leaderboard = data['leaderboardRows']

# %%
database = []
for i in range(len(leaderboard)):
    competitors = leaderboard[i]['entrant']['competitorName']
    for j in range(len(leaderboard[i]['scores'])):
        workout_number = leaderboard[i]['scores'][j]['ordinal']
        times = leaderboard[i]['scores'][j]['time']
        ranks = leaderboard[i]['scores'][j]['rank']
        score = leaderboard[i]['scores'][j]['breakdown']
        database.append([competitors, workout_number, times, ranks, score])

# %%
full_data = pd.DataFrame(database, columns=['competitors', 'ordinals', 'times', 'ranks', 'score'])

# %% [markdown]
# # Event 1

# %%
event_1 = full_data[full_data['ordinals']==1].sort_values('times')

# %%
from datetime import datetime
total_seconds = []
for i, j in event_1.iterrows(): 
    datetime_convert = datetime.strptime(j['times'],'%M:%S')
    total_seconds.append(datetime_convert.second + datetime_convert.minute*60)

# %%
event_1['total_seconds'] = total_seconds

lst = list(event_1['total_seconds']-min(event_1['total_seconds']))
event_1['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_1
# Out:
#                    competitors  ordinals times ranks    score  total_seconds  \
# 0                Mathew Fraser         1  3:08     1  100 pts            188
# 7                  Noah Ohlsen         1  3:55     2   96 pts            235
# 112               Scott Tetlow         1  3:58    3T   92 pts            238
# 70                Bayden Brown         1  3:58    3T   92 pts            238
# 77               Jacob Heppner         1  3:59     5   84 pts            239
# 28               Jeffrey Adler         1  4:00     6   80 pts            240
# 147               Luke Schafer         1  4:01     7   76 pts            241
# 63            Samuel Cournoyer         1  4:03     8   72 pts            243
# 168             Griffin Roelle         1  4:07     9   68 pts            247
# 42                 Jonne Koski         1  4:10   10T   64 pts            250
# 14             Justin Medeiros         1  4:10   10T   64 pts            250
# ...

# %%
# %matplotlib
import numpy as np

fig, ax = plt.subplots()

names = list(event_1['competitors'])
y_pos = np.arange(len(names))
performance = list(event_1['total_seconds'])

ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(names)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time To Finish (Seconds)')
ax.set_title('Crossfit Games 2020 Event 1: Friendly Fran')
print(y_pos[0], performance[0])

plt.barh(y_pos[0], performance[0], color=['red'])
plt.text(performance[0]+2, 0, '3:08', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[1], performance[1], color=['red'])
plt.text(performance[1]+2, 1, '3:55', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[2], performance[2], color=['red'])
plt.text(performance[2]+2, 2, '3:58', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[-1], performance[-1], color=['red'])
plt.text(performance[-1]+2, 29, '5:48', color='black', fontweight='bold', fontsize=10, ha='left', va='center')

fig.subplots_adjust(left=.25)
plt.xlim(150,performance[-1]+20)
plt.show()
# Out:
# Using matplotlib backend: MacOSX
# 0 188

# %%
# %matplotlib
import numpy as np

fig, ax = plt.subplots()

names = list(event_1['competitors'])
y_pos = np.arange(len(names))
performance = list(int(str(i)[:-4]) for i in event_1['score'])

ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(names)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time To Finish (Seconds)')
ax.set_title('Actual Scores: Friendly Fran')

plt.barh(y_pos[0], performance[0], color=['red'])
plt.text(performance[0]+2, 0, '3:08, 100 pts', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[1], performance[1], color=['red'])
plt.text(performance[1]+2, 1, '3:55, 96 pts', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[2], performance[2], color=['red'])
plt.text(performance[2]+2, 2, '3:58, 92 pts', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[-1], performance[-1], color=['red'])
plt.text(performance[-1]+2, 29, '5:48, 1 pt', color='black', fontweight='bold', fontsize=10, ha='left', va='center')

fig.subplots_adjust(left=0.2)
plt.xlim(0,performance[0]+20)
plt.show()
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# # Event 2

# %%
event_2 = full_data[full_data['ordinals']==2].sort_values('times')

# %%
event_2['times'] = [int(i) for i in event_2['times']]
lst = list(event_2['times']-min(event_2['times']))
event_2['adjusted_score'] = [i*(100/max(lst)) for i in lst]

# %%
event_2 = event_2.sort_values('adjusted_score', ascending=False)

# %%
event_2
# Out:
#                    competitors  ordinals  times ranks    score  adjusted_score
# 169             Griffin Roelle         2    490     1  100 pts      100.000000
# 162          Tyler Christophel         2    457     2   96 pts       74.015748
# 15             Justin Medeiros         2    437     3   92 pts       58.267717
# 1                Mathew Fraser         2    425     4   88 pts       48.818898
# 36              Chandler Smith         2    424     5   84 pts       48.031496
# 71                Bayden Brown         2    422     6   80 pts       46.456693
# 29               Jeffrey Adler         2    418     7   76 pts       43.307087
# 127               Travis Mayer         2    416     9   68 pts       41.732283
# 106            Alexandre Caron         2    416     8   72 pts       41.732283
# 22                Samuel Kwant         2    413    10   64 pts       39.370079
# 183              Adam Davidson         2    412    12   56 pts       38.582677
# ...

# %%
# %matplotlib
import numpy as np

fig, ax = plt.subplots()

names = list(event_2['competitors'])
y_pos = np.arange(len(names))
performance = list(event_2['adjusted_score'])

ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(names)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Points')
ax.set_title('Crossfit Games 2020 Event 2: 1RM Front Squat')
print(y_pos[0], performance[0])

plt.barh(y_pos[0], performance[0], color=['red'])
plt.text(performance[0]+2, 0, '490#, 100 pts', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[1], performance[1], color=['red'])
plt.text(performance[1]+2, 1, '457#, 74.02 pts', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[2], performance[2], color=['red'])
plt.text(performance[2]+2, 2, '437#, 58.27 pts', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[-1], performance[-1], color=['red'])
plt.text(performance[-1]+2, 29, '363#, 0 pts', color='black', fontweight='bold', fontsize=10, ha='left', va='center')

fig.subplots_adjust(left=.25)
plt.xlim(0,performance[0]+20)
plt.show()
# Out:
# Using matplotlib backend: MacOSX
# 0 100.0

# %% [markdown]
# # Event 3

# %%
event_3 = full_data[full_data['ordinals']==3].sort_values('times')

# %%
total_seconds = []
for i, j in event_3.iterrows(): 
    datetime_convert = datetime.strptime(j['times'],'%M:%S')
    total_seconds.append(datetime_convert.second + datetime_convert.minute*60)

# %%
event_3['total_seconds'] = total_seconds

lst = list(event_3['total_seconds']-min(event_3['total_seconds']))
event_3['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_3
# Out:
#                    competitors  ordinals times ranks    score  total_seconds  \
# 2                Mathew Fraser         3  2:44     1  100 pts            164
# 9                  Noah Ohlsen         3  2:56     2   96 pts            176
# 44                 Jonne Koski         3  3:29     3   92 pts            209
# 65            Samuel Cournoyer         3  3:39     4   88 pts            219
# 121                 Jay Crouch         3  3:45     5   84 pts            225
# 37              Chandler Smith         3  3:59     6   80 pts            239
# 114               Scott Tetlow         3  4:02     7   76 pts            242
# 58             Patrick Vellner         3  4:10     8   72 pts            250
# 93                 Tim Paulson         3  4:20     9   68 pts            260
# 177                Khan Porter         3  4:35    10   64 pts            275
# 156            Brandon Luckett         3  4:40    11   60 pts            280
# ...

# %% [markdown]
# # Event 4

# %%
event_4 = full_data[full_data['ordinals']==4].sort_values('times')

# %%
total_seconds = []
for i, j in event_4.iterrows(): 
    datetime_convert = datetime.strptime(j['times'],'%M:%S.%f')
    total_seconds.append(datetime_convert.second + datetime_convert.minute*60+ datetime_convert.microsecond*1e-6)

# %%
event_4['total_seconds'] = total_seconds

lst = list(event_4['total_seconds']-min(event_4['total_seconds']))
event_4['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_4
# Out:
#                    competitors  ordinals    times ranks    score  \
# 87            Roman Khrennikov         4  2:48.90     1  100 pts
# 178                Khan Porter         4  2:51.70     2   96 pts
# 24                Samuel Kwant         4  2:53.30     3   92 pts
# 129               Travis Mayer         4  2:54.10     4   88 pts
# 101             Brent Fikowski         4  2:54.20     5   84 pts
# 73                Bayden Brown         4  2:54.70     6   80 pts
# 59             Patrick Vellner         4  2:54.80     7   76 pts
# 3                Mathew Fraser         4  2:55.20     8   72 pts
# 206             David Shorunke         4  2:57.00    9T   68 pts
# 94                 Tim Paulson         4  2:57.00    9T   68 pts
# 31               Jeffrey Adler         4  2:57.30    11   60 pts
# 136                 Cole Sager         4  2:57.60    12   56 pts
# 157            Brandon Luckett         4  2:57.90    13   52 pts
# ...

# %% [markdown]
# # Event 5

# %%
event_5 = full_data[full_data['ordinals']==5].sort_values('times')

# %%
total_seconds = []
for i, j in event_5.iterrows(): 
    if 'CAP' in j['times']:
        total_seconds.append(1800+28)
    else:
        datetime_convert = datetime.strptime(j['times'],'%M:%S')
        total_seconds.append(datetime_convert.second + datetime_convert.minute*60)

# %%
event_5['total_seconds'] = total_seconds

lst = list(event_5['total_seconds']-min(event_5['total_seconds']))
event_5['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_5
# Out:
#                    competitors  ordinals   times ranks    score  \
# 4                Mathew Fraser         5   17:50     1  100 pts
# 18             Justin Medeiros         5   18:19     2   96 pts
# 39              Chandler Smith         5   18:43     3   92 pts
# 88            Roman Khrennikov         5   19:16     4   88 pts
# 53   Björgvin Karl Guðmundsson         5   19:24     5   84 pts
# 32               Jeffrey Adler         5   19:36     6   80 pts
# 11                 Noah Ohlsen         5   19:40     7   76 pts
# 25                Samuel Kwant         5   19:47    8T   72 pts
# 109            Alexandre Caron         5   19:47    8T   72 pts
# 137                 Cole Sager         5   19:50    10   64 pts
# 151               Luke Schafer         5   19:59    11   60 pts
# 81               Jacob Heppner         5   20:01    12   56 pts
# 74                Bayden Brown         5   20:10    13   52 pts
# 116               Scott Tetlow         5   20:17    14   49 pts
# ...

# %% [markdown]
# # Event 6

# %%
event_6 = full_data[full_data['ordinals']==6].sort_values('times')

# %%
event_6
# Out:
#                    competitors  ordinals times ranks    score
# 124                 Jay Crouch         6  1:00   20T   31 pts
# 40              Chandler Smith         6  1:00   20T   31 pts
# 103             Brent Fikowski         6  1:02   18T   37 pts
# 194             Rogelio Gamboa         6  1:02   18T   37 pts
# 138                 Cole Sager         6  1:05   16T   43 pts
# 82               Jacob Heppner         6  1:05   16T   43 pts
# 131               Travis Mayer         6  1:06    15   46 pts
# 117               Scott Tetlow         6  1:07    14   49 pts
# 159            Brandon Luckett         6  1:10    13   52 pts
# 145              Saxon Panchik         6  1:14   11T   60 pts
# 19             Justin Medeiros         6  1:14   11T   60 pts
# 68            Samuel Cournoyer         6  1:17    10   64 pts
# 61             Patrick Vellner         6  1:19    8T   72 pts
# 89            Roman Khrennikov         6  1:19    8T   72 pts
# ...

# %%
total_seconds = []
for i, j in event_6.iterrows(): 
    try:
        datetime_convert = datetime.strptime(j['times'],'%M:%S')
        total_seconds.append(datetime_convert.second + datetime_convert.minute*60)
    except:
        datetime_convert = datetime.strptime(j['times'],':%S')
        total_seconds.append(datetime_convert.second + datetime_convert.minute*60)

# %%
event_6['total_seconds'] = total_seconds

lst = list(event_6['total_seconds']-min(event_6['total_seconds']))
event_6['adjusted_score'] = [i*(100/max(lst)) for i in lst]

# %%
event_6
# Out:
#                    competitors  ordinals times ranks    score  total_seconds  \
# 124                 Jay Crouch         6  1:00   20T   31 pts             60
# 40              Chandler Smith         6  1:00   20T   31 pts             60
# 103             Brent Fikowski         6  1:02   18T   37 pts             62
# 194             Rogelio Gamboa         6  1:02   18T   37 pts             62
# 138                 Cole Sager         6  1:05   16T   43 pts             65
# 82               Jacob Heppner         6  1:05   16T   43 pts             65
# 131               Travis Mayer         6  1:06    15   46 pts             66
# 117               Scott Tetlow         6  1:07    14   49 pts             67
# 159            Brandon Luckett         6  1:10    13   52 pts             70
# 145              Saxon Panchik         6  1:14   11T   60 pts             74
# 19             Justin Medeiros         6  1:14   11T   60 pts             74
# ...

# %% [markdown]
# # Event 7

# %%
event_7 = full_data[full_data['ordinals']==7].sort_values('times').iloc[1:]

# %%
total_seconds = []
for i, j in event_7.iterrows(): 
    datetime_convert = datetime.strptime(j['times'],'%M:%S')
    total_seconds.append(datetime_convert.second + datetime_convert.minute*60)

# %%
event_7['total_seconds'] = total_seconds

lst = list(event_7['total_seconds']-min(event_7['total_seconds']))
event_7['adjusted_score'] = [100 - i*(100/max(lst)) for i in lst]

# %%
event_7
# Out:
#                    competitors  ordinals  times ranks    score  total_seconds  \
# 55   Björgvin Karl Guðmundsson         7  10:02    10   64 pts            602
# 41              Chandler Smith         7  10:09    11   60 pts            609
# 111            Alexandre Caron         7  10:12    12   56 pts            612
# 48                 Jonne Koski         7  10:16    13   52 pts            616
# 125                 Jay Crouch         7  10:22    14   49 pts            622
# 153               Luke Schafer         7  10:23    15   46 pts            623
# 76                Bayden Brown         7  10:24    16   43 pts            624
# 132               Travis Mayer         7  10:43    17   40 pts            643
# 202                  Pete Shaw         7  10:47    18   37 pts            647
# 139                 Cole Sager         7  10:56    19   34 pts            656
# 195             Rogelio Gamboa         7  10:57   20T   31 pts            657
# ...

# %% [markdown]
# # Final Analysis

# %%
frames = [event_1, event_2, event_3, event_4, event_5, event_6, event_7]
final_df = pd.concat(frames)[['competitors','adjusted_score', 'score']]
final_df['score'] = [int(i[:-4]) for i in final_df['score']]
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
adjusted_placements = final_df.groupby('competitors').agg({'adjusted_score':'sum','score':'sum'}).sort_values('adjusted_score', ascending=False)

# %%
adjusted_placements['adjusted_placement'] = [i+1 for i in range(len(adjusted_placements))]

# %%
actual_placement = []

for i in range(len(leaderboard)):
    competitors = leaderboard[i]['entrant']['competitorName']
    placement = leaderboard[i]['overallRank']
    actual_placement.append((competitors, placement))

# %%
final_placements = pd.DataFrame(actual_placement, columns=['competitors','actual_placement'])

# %%
final_placements
# Out:
#                   competitors actual_placement
# 0               Mathew Fraser                1
# 1                 Noah Ohlsen                2
# 2             Justin Medeiros                3
# 3                Samuel Kwant                4
# 4               Jeffrey Adler                5
# 5              Chandler Smith                6
# 6                 Jonne Koski                7
# 7   Björgvin Karl Guðmundsson                8
# 8             Patrick Vellner                9
# 9            Samuel Cournoyer               10
# 10               Bayden Brown               11
# 11              Jacob Heppner               12
# 12           Roman Khrennikov               13
# 13                Tim Paulson               14
# 14             Brent Fikowski               15
# 15            Alexandre Caron               16
# 16               Scott Tetlow               17
# 17                 Jay Crouch               18
# 18               Travis Mayer               19
# ...

# %%
df = final_placements.join(adjusted_placements, how='inner', on='competitors')
df = df[['competitors','score','actual_placement','adjusted_score','adjusted_placement']]

# %%
df
# Out:
#                   competitors  score actual_placement  adjusted_score  \
# 0               Mathew Fraser    656                1      614.493940
# 1                 Noah Ohlsen    488                2      485.808866
# 2             Justin Medeiros    480                3      483.999844
# 3                Samuel Kwant    449                4      470.133952
# 4               Jeffrey Adler    420                5      415.607551
# 5              Chandler Smith    418                6      436.563956
# 6                 Jonne Koski    410                7      448.659755
# 7   Björgvin Karl Guðmundsson    406                8      429.957477
# 8             Patrick Vellner    405                9      449.373045
# 9            Samuel Cournoyer    395               10      438.853257
# 10               Bayden Brown    382               11      404.026452
# 11              Jacob Heppner    344               12      397.000942
# ...

# %%
# df.to_csv('Adjusted_Results/Men_2020.csv')

# %%
# %matplotlib
import numpy as np

fig, ax = plt.subplots()

names = list(df['competitors'])
y_pos = np.arange(len(names))
performance = list(df['adjusted_score'])

ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(names)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Points')
ax.set_title('Crossfit Games 2020 Women Final Standings')
print(y_pos[0], performance[0])

plt.barh(y_pos[0], performance[0], color=['cyan'])
plt.text(performance[0]+2, 0, 'No Change', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[1], performance[1], color=['cyan'])
plt.text(performance[1]+2, 1, 'No Change', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[2], performance[2], color=['cyan'])
plt.text(performance[2]+2, 2, 'No Change', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[3], performance[3], color=['cyan'])
plt.text(performance[3]+2, 3, 'No Change', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[4], performance[4], color=['red'])
plt.text(performance[4]+2, 4, '5th to 11th', color='black', fontweight='bold', fontsize=10, ha='left', va='center')
plt.barh(y_pos[8], performance[8], color=['red'])
plt.text(performance[8]+2, 8, '9th to 5th', color='black', fontweight='bold', fontsize=10, ha='left', va='center')

fig.subplots_adjust(left=.25)
plt.xlim(0,performance[0]+100)
plt.show()
# Out:
# Using matplotlib backend: MacOSX
# 0 614.4939395138423

# %%
event_1_scores = event_1[['competitors', 'ranks', 'score', 'adjusted_score']]
event_1_scores.rename(columns = {'ranks':'ranks_1', 'score':'score_1', 'adjusted_score':'adjusted_score_1'}, inplace = True) 

event_2_scores = event_2[['competitors', 'ranks', 'score', 'adjusted_score']]
event_2_scores.rename(columns = {'ranks':'ranks_2', 'score':'score_2', 'adjusted_score':'adjusted_score_2'}, inplace = True) 

event_3_scores = event_3[['competitors', 'ranks', 'score', 'adjusted_score']]
event_3_scores.rename(columns = {'ranks':'ranks_3', 'score':'score_3', 'adjusted_score':'adjusted_score_3'}, inplace = True) 

event_4_scores = event_4[['competitors', 'ranks', 'score', 'adjusted_score']]
event_4_scores.rename(columns = {'ranks':'ranks_4', 'score':'score_4', 'adjusted_score':'adjusted_score_4'}, inplace = True) 

event_5_scores = event_5[['competitors', 'ranks', 'score', 'adjusted_score']]
event_5_scores.rename(columns = {'ranks':'ranks_5', 'score':'score_5', 'adjusted_score':'adjusted_score_5'}, inplace = True) 

event_6_scores = event_6[['competitors', 'ranks', 'score', 'adjusted_score']]
event_6_scores.rename(columns = {'ranks':'ranks_6', 'score':'score_6', 'adjusted_score':'adjusted_score_6'}, inplace = True) 

event_7_scores = event_7[['competitors', 'ranks', 'score', 'adjusted_score']]
event_7_scores.rename(columns = {'ranks':'ranks_7', 'score':'score_7', 'adjusted_score':'adjusted_score_7'}, inplace = True)
# Out:
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
merge_1 = event_1_scores.merge(event_2_scores, on='competitors', how='left')
merge_2 = merge_1.merge(event_3_scores, on='competitors', how='left')
merge_3 = merge_2.merge(event_4_scores, on='competitors', how='left')
merge_4 = merge_3.merge(event_5_scores, on='competitors', how='left')
merge_5 = merge_4.merge(event_6_scores, on='competitors', how='left')
merge_6 = merge_5.merge(event_7_scores, on='competitors', how='left')
merge_7 = merge_6.merge(df, on='competitors', how='left')

final_df = merge_7.sort_values('score', ascending=False)

# %%
# %matplotlib
import numpy as np

fig, ax = plt.subplots()

names = list(final_df['competitors'])
y_pos = np.arange(len(names))
perf_1 = list(final_df['adjusted_score_1'])
perf_2 = list(final_df['adjusted_score_1'] + final_df['adjusted_score_2'])
perf_3 = list(perf_2 + final_df['adjusted_score_3'])
perf_4 = list(perf_3 + final_df['adjusted_score_4'])
perf_5 = list(perf_4 + final_df['adjusted_score_5'])
perf_6 = list(perf_5 + final_df['adjusted_score_6'])
perf_7 = list(perf_6 + final_df['adjusted_score_7'])


ax.barh(y_pos, perf_7, label='Event 7') 
ax.barh(y_pos, perf_6, label='Event 6') 
ax.barh(y_pos, perf_5, label='Event 5') 
ax.barh(y_pos, perf_4, label='Event 4') 
ax.barh(y_pos, perf_3, label='Event 3') 
ax.barh(y_pos, perf_2, label='Event 2') 
ax.barh(y_pos, perf_1, label='Event 1')


ax.set_yticks(y_pos)
ax.set_yticklabels(names)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Points')
ax.set_title('Crossfit Games 2020 Stage 1 Men Adjusted Standings')

# plt.barh(y_pos[0], perf_7[0], color=['cyan'])
plt.text(perf_7[0]+2, 0, 'No Change', color='red', fontweight='bold', fontsize=10, ha='left', va='center')
# plt.barh(y_pos[1], perf_7[1], color=['cyan'])
plt.text(perf_7[1]+2, 1, 'No Change', color='red', fontweight='bold', fontsize=10, ha='left', va='center')
# plt.barh(y_pos[2], perf_7[2], color=['cyan'])
plt.text(perf_7[2]+2, 2, 'No Change', color='red', fontweight='bold', fontsize=10, ha='left', va='center')
# plt.barh(y_pos[3], perf_7[3], color=['cyan'])
plt.text(perf_7[3]+2, 3, 'No Change', color='red', fontweight='bold', fontsize=10, ha='left', va='center')
# plt.barh(y_pos[4], perf_7[4], color=['red'])
plt.text(perf_7[4]+2, 4, '5th to 11th', color='red', fontweight='bold', fontsize=10, ha='left', va='center')
# plt.barh(y_pos[8], perf_7[8], color=['red'])
plt.text(perf_7[8]+2, 8, '9th to 5th', color='red', fontweight='bold', fontsize=10, ha='left', va='center')

fig.subplots_adjust(left=.25)
plt.xlim(0,perf_7[0]+100)

handles, labels = plt.gca().get_legend_handles_labels()
order = [6,5,4,3,2,1,0]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order], loc='center right')

plt.show()
# Out:
# Using matplotlib backend: MacOSX

# %%
list(merge_6['adjusted_score_1'])
list(merge_6['adjusted_score_1'] + merge_6['adjusted_score_2'])
# Out:
# [148.8188976377953,
#  99.98495411003562,
#  93.349716635739,
#  114.60955915542405,
#  80.90175033853252,
#  110.18606750589298,
#  80.4152665630172,
#  90.16500325994282,
#  162.4203821656051,
#  86.49380610863133,
#  118.77727067556046,
#  94.36782185666283,
#  81.91985555945634,
#  56.05095541401274,
#  76.0369125833793,
#  69.88815888459803,
#  126.88199006971263,
#  90.32549275289634,
#  59.2808064597021,
#  95.8021966999348,
#  62.2448467826872,
#  82.53172175134159,
#  41.06524900947891,
#  78.03801594864336,
#  76.7641305983249,
#  72.34063894879384,
#  46.958222578865545,
#  51.98354982697228,
#  31.024625106575055,
#  11.023622047244094]
